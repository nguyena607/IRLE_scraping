# %%
import json
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
file_path = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_ca_fullserv.csv"
ca_ff = pd.read_csv(file_path)
file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/uszips.csv"
ca_zip_count = pd.read_csv(file_path_2)
file_path_3 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_ca_ff_03222024.csv"
example = pd.read_csv(file_path_3)

# %%
#Drop all the columns we don't need 
ca_ff_ = ca_ff.drop(columns=['Unnamed: 0', 'inputted_location','restaurant_distance'])
ca_ff_ = ca_ff_.dropna(subset=['restaurant_location'])

# %%
ca_zip_count = ca_zip_count[['zip', 'county_name']]

# %%
#restaurant_rating cleaning 
# Ensure the column is of string type using .loc
ca_ff_.loc[:, 'restaurant_rating'] = ca_ff_['restaurant_rating'].astype(str)

# Count rows containing 'mi'
rows_with_mi = ca_ff_['restaurant_rating'].str.contains('mi').sum()
print("Number of rows with 'mi' in restaurant rating:", rows_with_mi)

# Replace invalid ratings ending with 'mi' with '0' using .loc
ca_ff_.loc[:, 'restaurant_rating'] = ca_ff_['restaurant_rating'].str.replace(r'.*mi$', '0', regex=True)
# Out:
# Number of rows with 'mi' in restaurant rating: 0

# %%
#converting data types 
ca_ff_['restaurant_name'] = ca_ff_['restaurant_name'].astype('string')
ca_ff_['menu_item'] = ca_ff_['menu_item'].astype('string')
ca_ff_['menu_item'] = ca_ff_['menu_item'].str.replace(r'\s+', ' ', regex=True)
ca_ff_['restaurant_location'] = ca_ff_['restaurant_location'].astype('string')
ca_ff_['restaurant_rating'] = ca_ff_['restaurant_rating'].str.strip().astype(float)

# %%
#cleaning up string columns 

ca_ff_['menu_item'] = ca_ff_['menu_item'].str.lower()
ca_ff_['restaurant_location'] = ca_ff_['restaurant_location'].str.lower()
ca_ff_['restaurant_name'] = ca_ff_['restaurant_name'].str.replace('_', ' ')

#remove special characters
ca_ff_['menu_item'] = ca_ff_['menu_item'].apply(lambda x: ''.join(ch for ch in x if ch.isalnum() or ch.isspace()))
ca_ff_
# Out:
#        Unnamed: 0.1  restaurant_name           menu_item  menu_item_price  \
# 0                 0  BJs Restaurants   brewhouse sampler            19.75
# 1                 1  BJs Restaurants        bonein wings            18.25
# 2                 2  BJs Restaurants      boneless wings            17.25
# 3                 3  BJs Restaurants  bjs original wings            18.25
# 4                 4  BJs Restaurants   avocado egg rolls            17.25
# ...             ...              ...                 ...              ...
# 72078         70542      TGI Fridays         plasticware             0.00
# 72079         70543      TGI Fridays             ketchup             0.00
# 72080         70544      TGI Fridays             mustard             0.00
# 72081         70545      TGI Fridays              straws             0.00
# 72082         70546      TGI Fridays                mayo             0.00
#
#                                    restaurant_location  restaurant_rating  \
# 0                       1200, roseville, ca, 95678, us                4.4
# 1                       1200, roseville, ca, 95678, us                4.4
# 2                       1200, roseville, ca, 95678, us                4.4
# 3                       1200, roseville, ca, 95678, us                4.4
# 4                       1200, roseville, ca, 95678, us                4.4
# ...                                                ...                ...
# 72078  2795 tapo canyon rd, simi valley, ca, 93063, us                4.5
# 72079  2795 tapo canyon rd, simi valley, ca, 93063, us                4.5
# 72080  2795 tapo canyon rd, simi valley, ca, 93063, us                4.5
# 72081  2795 tapo canyon rd, simi valley, ca, 93063, us                4.5
# 72082  2795 tapo canyon rd, simi valley, ca, 93063, us                4.5
#
#       number_of_ratings
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 72078              600+
# 72079              600+
# 72080              600+
# 72081              600+
# 72082              600+
#
# [71949 rows x 7 columns]

# %%
def price_list(x):
    return list(x)

def mean_non_zero(x):
    return np.mean(x[x != 0]) if np.any(x != 0) else 0

def median_non_zero(x):
    return np.median(x[x != 0]) if np.any(x != 0) else 0

def std_non_zero(x):
    return np.std(x[x != 0]) if np.any(x != 0) else 0

# %%
#Outback Steakhouse 

ca_ff_outback = ca_ff_[ca_ff_['restaurant_name'] == 'Outback Steakhouse']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_outback = ca_ff_outback.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_outback.columns = [' '.join(col).strip() for col in grouped_outback.columns.values]

# %%
#Second part of grouping 
outback_lst = ['aussie fries','boomerang cheeseburger','the outbacker burger', ]

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_outback = ca_ff_outback[ca_ff_outback['menu_item'].isin(outback_lst)].sort_values('menu_item')
menu_items_outback = menu_items_outback.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_outback_2 = menu_items_outback.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_outback_2[['fries', 'cheeseburger', 'hamburger']] = grouped_outback_2['menu_item_price'].apply(pd.Series)
grouped_outback_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_outback = pd.merge(grouped_outback, grouped_outback_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_outback['combo'] = np.nan
merged_outback['specialty_item'] = np.nan
merged_outback
# Out:
#        restaurant_name                                restaurant_location  \
# 0   Outback Steakhouse  12001 harbor boulevard, garden grove, ca, 9284...
# 1   Outback Steakhouse   12400b amargosa road, victorville, ca, 92392, us
# 2   Outback Steakhouse     1246 great mall drive, milpitas, ca, 95035, us
# 3   Outback Steakhouse                      12850, norwalk, ca, 90650, us
# 4   Outback Steakhouse              1340 howe ave., sac ii, ca, 95825, us
# 5   Outback Steakhouse       1361 fitzgerald drive, pinole, ca, 94564, us
# 6   Outback Steakhouse           14701 pomerado rd., poway, ca, 92064, us
# 7   Outback Steakhouse          1476 n. azusa ave., covina, ca, 91722, us
# 8   Outback Steakhouse   150a longbrook way, pleasant hill, ca, 94523, us
# 9   Outback Steakhouse   1640 camino del rio n., san diego, ca, 92108, us
# 10  Outback Steakhouse      166 e. huntington dr., arcadia, ca, 91006, us
# 11  Outback Steakhouse      1761 n. victory place, burbank, ca, 91504, us
# 12  Outback Steakhouse                     177, san marcos, ca, 92069, us
# 13  Outback Steakhouse     18711devonshire st., northridge, ca, 91324, us
# 14  Outback Steakhouse     20 w. shoreline dr., long beach, ca, 90802, us
# 15  Outback Steakhouse  2045-d w. briggsmore ave., modesto, ca, 95350, us
# 16  Outback Steakhouse           2341 lockwood st., oxnard, ca, 93030, us
# 17  Outback Steakhouse       25261n. the old rd., valencia, ca, 91381, us
# 18  Outback Steakhouse       25322 cabot rd., laguna hills, ca, 92653, us
# 19  Outback Steakhouse  26652 portola pkwy., foothill ranch, ca, 92610...
# 20  Outback Steakhouse    2980 plaza bonita, national city, ca, 91950, us
# 21  Outback Steakhouse         3525 w. carson st, torrance, ca, 90503, us
# 22  Outback Steakhouse        371 gellert blvd., daly city, ca, 94015, us
# 23  Outback Steakhouse    4004 south mooney blvd., visalia, ca, 93277, us
# 24  Outback Steakhouse  4196 clairemont mesa blvd., san diego, ca, 921...
# 25  Outback Steakhouse        4350 century blvd, pittsburg, ca, 94565, us
# 26  Outback Steakhouse                       4492, ontario, ca, 91764, us
# 27  Outback Steakhouse    5051 stockdale hwy., bakersfield, ca, 93309, us
# 28  Outback Steakhouse         521 davis street, vacaville, ca, 95688, us
# 29  Outback Steakhouse        530 n. mountain ave., upland, ca, 91786, us
# 30  Outback Steakhouse           5305 clark ave., lakewood, ca, 90712, us
# 31  Outback Steakhouse                    549, westminster, ca, 92683, us
# 32  Outback Steakhouse  620 e. hospitality lane, san bernardino, ca, 9...
# 33  Outback Steakhouse           6505 regional st., dublin, ca, 94568, us
# 34  Outback Steakhouse           722 jamacha rd., el cajon, ca, 92019, us
# 35  Outback Steakhouse        7221 laguna blvd., elk grove, ca, 95758, us
# 36  Outback Steakhouse         7575beach blvd., buena park, ca, 90620, us
#
#     menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                       18.765824                            12.99
# 1                       15.750000                            12.79
# 2                       20.328298                            17.49
# 3                       19.690000                            15.99
# 4                       19.518713                            14.99
# 5                       19.835918                            16.74
# 6                       15.448776                            12.39
# 7                       15.628431                            12.39
# 8                       17.408293                            14.24
# 9                       19.696863                            15.49
# 10                      19.421068                            14.99
# 11                      16.659787                            14.39
# 12                      19.690000                            15.99
# 13                      15.852178                            12.79
# 14                      15.874000                            13.39
# 15                      17.225714                            13.74
# 16                      18.626082                            13.99
# 17                      15.994040                            13.99
# 18                      15.750000                            12.79
# 19                      19.570392                            15.49
# 20                      19.782000                            16.74
# 21                      19.845000                            16.74
# 22                      16.732500                            12.99
# 23                      19.690000                            15.99
# 24                      19.664510                            15.49
# 25                      19.268431                            14.49
# 26                      19.538039                            15.49
# 27                      17.120120                            13.49
# 28                      19.538039                            15.49
# 29                      19.690000                            15.99
# 30                      15.874000                            13.39
# 31                      19.538039                            15.49
# 32                      15.874000                            13.39
# 33                      15.895600                            13.39
# 34                      19.812000                            16.74
# 35                      19.074536                            14.99
# 36                      19.477500                            15.49
#
#     menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                      13.927776                     4.5              100
# 1                      11.150016                     4.3              111
# 2                      14.370553                     4.3              104
# 3                      13.937520                     4.5              111
# 4                      14.020405                     4.4              111
# 5                      14.110209                     4.4              108
# 6                      10.761666                     4.6              108
# 7                      11.162288                     4.6              112
# 8                      12.956373                     4.6               94
# 9                      14.090501                     4.4              112
# 10                     13.935127                     4.6              113
# 11                     11.028443                     4.5              104
# 12                     13.937520                     4.4              111
# 13                     11.285900                     4.5              111
# 14                     11.136117                     4.2              110
# 15                     12.864251                     4.1               96
# 16                     13.054147                     4.5              106
# 17                     11.127543                     4.5              109
# 18                     11.150016                     4.5              111
# 19                     13.921024                     4.5              112
# 20                     13.976485                     4.4              110
# 21                     13.920146                     4.4              110
# 22                     12.168005                     4.4              448
# 23                     13.937520                     4.5              111
# 24                     14.122244                     4.5              112
# 25                     13.917323                     4.4              112
# 26                     13.952860                     4.6              112
# 27                     12.905278                     4.6               95
# 28                     13.952860                     4.5              224
# 29                     13.937520                     4.5              111
# 30                     11.136117                     4.5              110
# 31                     13.952860                     4.6              112
# 32                     11.136117                     4.6              110
# 33                     11.114717                     4.4              110
# 34                     13.953269                     4.4              110
# 35                     13.481123                     4.2              107
# 36                     13.917847                     4.5              114
#
#    number_of_ratings first  fries  cheeseburger  hamburger  combo  \
# 0                        1   4.99         10.49      15.99    NaN
# 1                     600+   3.99          8.39      12.79    NaN
# 2                        1   4.99         15.99        NaN    NaN
# 3                     800+   4.99         10.49      15.99    NaN
# 4                        1   4.99         10.49      15.99    NaN
# 5                     700+   4.99         10.49      15.99    NaN
# 6                        1   3.99          8.39      12.79    NaN
# 7                        1   3.99          8.39      12.79    NaN
# 8                     700+   4.99          7.49      14.49    NaN
# 9                        2   4.99         10.49      15.99    NaN
# 10                       1   4.99         10.49      15.99    NaN
# 11                       2   3.99          8.39      12.79    NaN
# 12                    800+   4.99         10.49      15.99    NaN
# 13                       1   3.99          8.39      12.79    NaN
# 14                       1   3.99          8.39      12.79    NaN
# 15                    340+   4.99          7.49      14.49    NaN
# 16                    500+   4.99         10.49      15.99    NaN
# 17                    600+   3.99          8.39      12.79    NaN
# 18                    900+   3.99          8.39      12.79    NaN
# 19                    500+   4.99         10.49      15.99    NaN
# 20                       1   4.99         10.49      15.99    NaN
# 21                    900+   4.99         10.49      15.99    NaN
# 22                       2   4.99          8.39      15.99    NaN
# 23                    320+   4.99         10.49      15.99    NaN
# 24                       1   4.99         10.49      15.99    NaN
# 25                    400+   4.99         10.49      15.99    NaN
# 26                       1   4.99         10.49      15.99    NaN
# 27                       1   4.99          7.49      14.49    NaN
# 28                    700+   4.99         10.49      15.99    NaN
# 29                    600+   4.99         10.49      15.99    NaN
# 30                       1   3.99          8.39      12.79    NaN
# 31                       1   4.99         10.49      15.99    NaN
# 32                    900+   3.99          8.39      12.79    NaN
# 33                    600+   3.99          8.39      12.79    NaN
# 34                       1   4.99         10.49      15.99    NaN
# 35                    370+   4.99         10.49      15.99    NaN
# 36                    500+   4.99         10.49      15.99    NaN
#
#     specialty_item
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN

# %%
#Red Robin

ca_ff_rr = ca_ff_[ca_ff_['restaurant_name'] == 'Red Robin']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_rr = ca_ff_rr.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_rr.columns = [' '.join(col).strip() for col in grouped_rr.columns.values]

# %%
#Second part of grouping 
rr_lst = ['reds cheeseburger','steak fries', ]

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_rr = ca_ff_rr[ca_ff_rr['menu_item'].isin(rr_lst)].sort_values('menu_item')
menu_items_rr = menu_items_rr.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_rr_2 = menu_items_rr.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_rr_2[['cheeseburger', 'fries']] = grouped_rr_2['menu_item_price'].apply(pd.Series)
grouped_rr_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_rr = pd.merge(grouped_rr, grouped_rr_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_rr['combo'] = np.nan
merged_rr['specialty_item'] = np.nan
merged_rr['hamburger'] = np.nan
merged_rr
# Out:
#    restaurant_name                                restaurant_location  \
# 0        Red Robin  1000 el paseo de saratoga, san jose, ca, 95130...
# 1        Red Robin   101 town center east, santa maria, ca, 93454, us
# 2        Red Robin                          1080, brea, ca, 92821, us
# 3        Red Robin                       112, lakewood, ca, 90712, us
# 4        Red Robin       1184 galleria blvd, roseville, ca, 95678, us
# 5        Red Robin     12007 harbor blvd, garden grove, ca, 92840, us
# 6        Red Robin  12271 foothill blvd, rancho cucamonga, ca, 917...
# 7        Red Robin      1274 el camino real, san bruno, ca, 94066, us
# 8        Red Robin  1307 west sunflower avenue, santa ana, ca, 927...
# 9        Red Robin            1370 tyler st, riverside, ca, 92503, us
# 10       Red Robin  14400 bear valley rd #405, victorville, ca, 92...
# 11       Red Robin  1555 simi town center way #670, simi valley, c...
# 12       Red Robin                     15610, whittier, ca, 90603, us
# 13       Red Robin       1631 w imperial hwy, la habra, ca, 90631, us
# 14       Red Robin  1815 hawthorne blvd, redondo beach, ca, 90278, us
# 15       Red Robin  18999 bear valley rd, apple valley, ca, 92308, us
# 16       Red Robin           1990 w florida ave, hemet, ca, 92545, us
# 17       Red Robin    200 e via rancho pkwy, escondido, ca, 92025, us
# 18       Red Robin    2015 s mooney blvd #505, visalia, ca, 93277, us
# 19       Red Robin       2031 bronze star dr, woodland, ca, 95776, us
# 20       Red Robin                      2199 n, orange, ca, 92865, us
# 21       Red Robin  2200 eastridge loop suite 2073, san jose, ca, ...
# 22       Red Robin         2367 claribel rd, riverbank, ca, 95367, us
# 23       Red Robin       2385 sand creek rd, brentwood, ca, 94513, us
# 24       Red Robin               2667 park ave, tustin, ca, 92606, us
# 25       Red Robin     2701 ming ave #g15, bakersfield, ca, 93304, us
# 26       Red Robin         27063 mcbean pkwy, valencia, ca, 91355, us
# 27       Red Robin         27476 lugonia ave, redlands, ca, 92374, us
# 28       Red Robin              30142 haun rd, menifee, ca, 92584, us
# 29       Red Robin  3030 plaza bonita rd #2520, national city, ca,...
# 30       Red Robin     3105 w monte vista ave, turlock, ca, 95380, us
# 31       Red Robin       3301 e main st #1511, ventura, ca, 93003, us
# 32       Red Robin             3385 w shaw ave, fresno, ca, 93711, us
# 33       Red Robin   360 palladio parkway #410, folsom, ca, 95630, us
# 34       Red Robin               3903 grand ave, chino, ca, 91710, us
# 35       Red Robin   3906 rivermark plaza, santa clara, ca, 95054, us
# 36       Red Robin      404-a sun valley mall, concord, ca, 94520, us
# 37       Red Robin  40820 winchester rd #1070, temecula, ca, 92591...
# 38       Red Robin      419 n mckinley st, mckinley st, ca, 92879, us
# 39       Red Robin           428 plaza dr, west covina, ca, 91790, us
# 40       Red Robin           5461 katella ave, cypress, ca, 90720, us
# 41       Red Robin      565 w arrow highway, san dimas, ca, 91773, us
# 42       Red Robin          681 town center dr, oxnard, ca, 93036, us
# 43       Red Robin          751 e joiner pkwy, lincoln, ca, 95648, us
# 44       Red Robin       7675 n blackstone ave, fresno, ca, 93711, us
# 45       Red Robin  7990 greenback ln unit j, citrus heights, ca, ...
# 46       Red Robin         8245 laguna blvd, elk grove, ca, 95758, us
# 47       Red Robin     9301 tampa ave #210, northridge, ca, 91324, us
# 48       Red Robin                950 shaw ave, clovis, ca, 93612, us
#
#     menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                       13.065676                            13.19
# 1                       12.493279                            11.69
# 2                       12.605126                            11.99
# 3                       12.605126                            11.99
# 4                       12.578235                            11.99
# 5                       12.960339                            12.49
# 6                       13.054407                            12.79
# 7                       12.711008                            11.99
# 8                       12.942542                            12.49
# 9                       12.912881                            12.49
# 10                      12.644237                            12.19
# 11                      12.871513                            11.99
# 12                      13.105254                            12.79
# 13                      13.035378                            12.39
# 14                      12.792542                            11.99
# 15                      12.871513                            11.99
# 16                      12.940000                            12.49
# 17                      12.971667                            12.19
# 18                      12.571667                            11.99
# 19                      12.871513                            11.99
# 20                      12.588291                            11.99
# 21                      13.008487                            12.39
# 22                      12.753115                            11.99
# 23                      12.940862                            12.99
# 24                      12.892542                            12.49
# 25                      12.605126                            11.99
# 26                      13.008487                            12.39
# 27                      12.666923                            12.39
# 28                      12.946522                            12.99
# 29                      13.231667                            13.19
# 30                      12.871513                            11.99
# 31                      12.507355                            11.99
# 32                      12.640847                            12.19
# 33                      12.605126                            11.99
# 34                      12.605126                            11.99
# 35                      12.914590                            11.99
# 36                      12.753115                            11.99
# 37                      12.671356                            12.19
# 38                      12.605126                            11.99
# 39                      12.605126                            11.99
# 40                      13.078136                            12.79
# 41                      13.008487                            12.39
# 42                      12.507355                            11.99
# 43                      12.871513                            11.99
# 44                      12.844622                            11.99
# 45                      13.020435                            12.99
# 46                      12.605126                            11.99
# 47                      12.605126                            11.99
# 48                      12.439038                            11.09
#
#     menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                       8.481864                     4.6              112
# 1                       8.346580                     4.5              123
# 2                       8.408106                     4.6              120
# 3                       8.408106                     4.6              120
# 4                       8.431745                     4.5              120
# 5                       8.527257                     4.6              119
# 6                       8.654778                     4.6              119
# 7                       8.334669                     4.5              480
# 8                       8.547085                     4.7              119
# 9                       8.574058                     4.5              119
# 10                      8.436730                     4.5              119
# 11                      8.546000                     4.6              120
# 12                      8.623643                     4.6              119
# 13                      8.620815                     4.6              120
# 14                      8.587560                     4.6              119
# 15                      8.546000                     4.4              120
# 16                      8.549554                     4.5              119
# 17                      8.619058                     4.6              121
# 18                      8.393192                     4.5              121
# 19                      8.546000                     4.4              120
# 20                      8.451369                     4.7              118
# 21                      8.645210                     4.4              120
# 22                      8.485612                     4.3              123
# 23                      8.644417                     4.3              117
# 24                      8.590441                     4.6              119
# 25                      8.408106                     4.2              120
# 26                      8.645210                     4.7              120
# 27                      8.462985                     4.6              118
# 28                      8.637060                     4.6              116
# 29                      8.658790                     4.5              109
# 30                      8.546000                     4.4              120
# 31                      8.379557                     4.4              122
# 32                      8.434662                     4.5              119
# 33                      8.408106                     4.3              120
# 34                      8.408106                     4.6              120
# 35                      8.560702                     4.6              123
# 36                      8.485612                     4.4              123
# 37                      8.412692                     4.6              119
# 38                      8.408106                     4.6              120
# 39                      8.408106                     4.6              120
# 40                      8.648456                     4.7              119
# 41                      8.645210                     4.6              120
# 42                      8.379557                     4.5              122
# 43                      8.546000                     4.5              120
# 44                      8.570094                     4.4              120
# 45                      8.643984                     4.3              116
# 46                      8.408106                     4.3              120
# 47                      8.408106                     4.6              120
# 48                      8.786911                     4.4              105
#
#    number_of_ratings first  cheeseburger  fries  combo  specialty_item  \
# 0                     600+          8.39   4.79    NaN             NaN
# 1                     360+          8.39   4.79    NaN             NaN
# 2                     700+          8.39   4.79    NaN             NaN
# 3                        1          8.39   4.79    NaN             NaN
# 4                     600+          8.39   4.79    NaN             NaN
# 5                        1          8.39   4.79    NaN             NaN
# 6                        1          8.39   4.79    NaN             NaN
# 7                     900+          8.39   4.79    NaN             NaN
# 8                        1          8.39   4.79    NaN             NaN
# 9                     480+          8.39   4.79    NaN             NaN
# 10                    600+          8.39   4.79    NaN             NaN
# 11                       1          8.39   4.79    NaN             NaN
# 12                       1          8.39   4.79    NaN             NaN
# 13                    800+          8.39   4.79    NaN             NaN
# 14                       1          8.39   4.79    NaN             NaN
# 15                    600+          8.39   4.79    NaN             NaN
# 16                    500+          8.39   4.79    NaN             NaN
# 17                    800+          8.39   4.79    NaN             NaN
# 18                    500+          8.39   4.79    NaN             NaN
# 19                    380+          8.39   4.79    NaN             NaN
# 20                       1          8.39   4.79    NaN             NaN
# 21                    900+          8.39   4.79    NaN             NaN
# 22                    360+          8.39   4.79    NaN             NaN
# 23                    450+          8.39   4.79    NaN             NaN
# 24                    800+          8.39   4.79    NaN             NaN
# 25                    700+          8.39   4.79    NaN             NaN
# 26                       1          8.39   4.79    NaN             NaN
# 27                       1          8.39   4.79    NaN             NaN
# 28                    900+          8.39   4.79    NaN             NaN
# 29                       1          8.39   4.79    NaN             NaN
# 30                    260+          8.39   4.79    NaN             NaN
# 31                    310+          8.39   4.79    NaN             NaN
# 32                       1          8.39   4.79    NaN             NaN
# 33                    340+          8.39   4.79    NaN             NaN
# 34                    900+          8.39   4.79    NaN             NaN
# 35                       1          8.39   4.79    NaN             NaN
# 36                    500+          8.39   4.79    NaN             NaN
# 37                    700+          8.39   4.79    NaN             NaN
# 38                    700+          8.39   4.79    NaN             NaN
# 39                       1          8.39   4.79    NaN             NaN
# 40                       1          8.39   4.79    NaN             NaN
# 41                       1          8.39   4.79    NaN             NaN
# 42                    480+          8.39   4.79    NaN             NaN
# 43                    310+          8.39   4.79    NaN             NaN
# 44                    700+          8.39   4.79    NaN             NaN
# 45                    900+          8.39   4.79    NaN             NaN
# 46                    600+          8.39   4.79    NaN             NaN
# 47                       1          8.39   4.79    NaN             NaN
# 48                       1          8.39   4.79    NaN             NaN
#
#     hamburger
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN

# %%
#Panera

ca_ff_panera = ca_ff_[ca_ff_['restaurant_name'] == 'Panera Bread']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_panera = ca_ff_panera.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_panera.columns = [' '.join(col).strip() for col in grouped_panera.columns.values]

# %%
grouped_panera['cheeseburger'] = np.nan
grouped_panera['hamburger'] = np.nan
grouped_panera['specialty_item'] = np.nan
grouped_panera['combo'] = np.nan
grouped_panera['fries'] = np.nan

# %%
grouped_panera
# Out:
#   restaurant_name                                restaurant_location  \
# 0    Panera Bread  1553 east prosperity avenue, tulare, ca, 93274...
# 1    Panera Bread      18663 bear valley rd, hesperia, ca, 92345, us
# 2    Panera Bread               2130 east, el segundo, ca, 90245, us
# 3    Panera Bread   3711 sports arena blvd, san diego, ca, 92110, us
# 4    Panera Bread   500 capitol mall #120, sacramento, ca, 95814, us
# 5    Panera Bread       511 north main street, corona, ca, 92880, us
# 6    Panera Bread   5895 katella ave suite f, cypress, ca, 90630, us
# 7    Panera Bread                   800 w, san marcos, ca, 92078, us
#
#    menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                      10.456197                             9.39
# 1                      10.831096                             9.39
# 2                      12.658794                            10.69
# 3                      12.632361                            10.69
# 4                      10.321293                             9.49
# 5                       9.061951                             9.94
# 6                      10.854493                             9.54
# 7                      12.681489                            10.69
#
#    menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                      9.144258                     4.7              149
# 1                      9.073737                     4.8              152
# 2                     13.464801                     4.7              147
# 3                     13.440634                     4.4              150
# 4                      8.424929                     4.6              153
# 5                      3.530331                     4.8               88
# 6                      9.123832                     4.6              144
# 7                     13.571155                     4.9              148
#
#   number_of_ratings first  cheeseburger  hamburger  specialty_item  combo  \
# 0                      85           NaN        NaN             NaN    NaN
# 1                    110+           NaN        NaN             NaN    NaN
# 2                    120+           NaN        NaN             NaN    NaN
# 3                      48           NaN        NaN             NaN    NaN
# 4                      42           NaN        NaN             NaN    NaN
# 5                    200+           NaN        NaN             NaN    NaN
# 6                      33           NaN        NaN             NaN    NaN
# 7                      52           NaN        NaN             NaN    NaN
#
#    fries
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN

# %%
#Denny

ca_ff_denny = ca_ff_[ca_ff_['restaurant_name'] == 'Denny']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_denny = ca_ff_denny.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_denny.columns = [' '.join(col).strip() for col in grouped_denny.columns.values]

# %%
#Second part of grouping 
denny_lst = ['seasoned fries','single cheeseburger']

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_denny = ca_ff_denny[ca_ff_denny['menu_item'].isin(denny_lst)].sort_values('menu_item')
menu_items_denny = menu_items_denny.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_denny_2 = menu_items_denny.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_denny_2[['fries', 'cheeseburger']] = grouped_denny_2['menu_item_price'].apply(pd.Series)
grouped_denny_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_denny = pd.merge(grouped_denny, grouped_denny_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_denny['combo'] = np.nan
merged_denny['specialty_item'] = np.nan
merged_denny['hamburger'] = np.nan

merged_denny
# Out:
#     restaurant_name                                restaurant_location  \
# 0             Denny  10 airport blvd, south san francisco, ca, 9408...
# 1             Denny     1000 w. steele lane, santa rosa, ca, 95403, us
# 2             Denny         1001 east capitol, san jose, ca, 95121, us
# 3             Denny     1019 east main st., santa maria, ca, 93454, us
# 4             Denny      1065 camino del rio, san diego, ca, 92108, us
# ..              ...                                                ...
# 151           Denny       8841 greenback ln, orangevale, ca, 95662, us
# 152           Denny      888 s figueroa st, los angeles, ca, 90017, us
# 153           Denny          910 saratoga ave, san jose, ca, 95129, us
# 154           Denny            955 manning ave, reedley, ca, 93654, us
# 155           Denny            975 e blanco rd, salinas, ca, 93901, us
#
#      menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                        13.317944                           12.670
# 1                        12.638396                           12.050
# 2                        12.335234                           11.940
# 3                        12.263084                           10.070
# 4                        12.423396                           10.955
# ..                             ...                              ...
# 151                      12.196176                           10.435
# 152                      12.418302                           11.090
# 153                      12.526389                           10.435
# 154                      11.453889                            9.740
# 155                      13.086154                           12.255
#
#      menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                        8.531761                     4.4              548
# 1                        8.633148                     4.3              136
# 2                        7.560002                     4.5              137
# 3                        7.391710                     4.5              137
# 4                        7.629890                     4.3              136
# ..                            ...                     ...              ...
# 151                      7.365105                     4.3              132
# 152                      7.746110                     4.2              136
# 153                      7.522060                     4.4              138
# 154                      6.862923                     3.1              138
# 155                      8.981899                     4.6              134
#
#     number_of_ratings first  fries  cheeseburger  combo  specialty_item  \
# 0                         1   6.22         17.77    NaN             NaN
# 1                      400+   6.54         17.98    NaN             NaN
# 2                      700+   6.02         17.56    NaN             NaN
# 3                      270+   5.81         18.29    NaN             NaN
# 4                      700+   6.02         18.39    NaN             NaN
# ..                      ...    ...           ...    ...             ...
# 151                    260+   6.02         17.46    NaN             NaN
# 152                       3   6.69         17.99    NaN             NaN
# 153                    600+   5.81         19.12    NaN             NaN
# 154                      14   5.59         16.49    NaN             NaN
# 155                    250+   6.74         18.29    NaN             NaN
#
#      hamburger
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 151        NaN
# 152        NaN
# 153        NaN
# 154        NaN
# 155        NaN
#
# [156 rows x 13 columns]

# %%
#Applebee

ca_ff_apple = ca_ff_[ca_ff_['restaurant_name'] == 'Applebee']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_apple = ca_ff_apple.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_apple.columns = [' '.join(col).strip() for col in grouped_apple.columns.values]

# %%
#Second part of grouping 
apple_lst = ['classic burger', 'classic cheeseburger']

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_apple = ca_ff_apple[ca_ff_apple['menu_item'].isin(apple_lst)].sort_values('menu_item')
menu_items_apple = menu_items_apple.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_apple_2 = menu_items_apple.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_apple_2[['hamburger', 'cheeseburger']] = grouped_apple_2['menu_item_price'].apply(pd.Series)
grouped_apple_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_apple = pd.merge(grouped_apple, grouped_apple_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_apple['combo'] = np.nan
merged_apple['specialty_item'] = np.nan
merged_apple['fries'] = np.nan


merged_apple
# Out:
#    restaurant_name                                restaurant_location  \
# 0         Applebee      1021 n. milliken ave., ontario, ca, 91764, us
# 1         Applebee  1041 admiral callaghan lane, vallejo, ca, 9459...
# 2         Applebee      107 fletcher parkway, el cajon, ca, 92020, us
# 3         Applebee  10709 foothill blvd, rancho cucamonga, ca, 917...
# 4         Applebee  1105 s. green valley road, watsonville, ca, 95...
# ..             ...                                                ...
# 72        Applebee           8931 brooks rd s, windsor, ca, 95492, us
# 73        Applebee     899 east spring st, signal hill, ca, 90755, us
# 74        Applebee          9000 ming ave, bakersfield, ca, 93311, us
# 75        Applebee  9480 east mira mesa blvd., san diego, ca, 9212...
# 76        Applebee              98 shaw avenue, clovis, ca, 93612, us
#
#     menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                       24.468151                            17.49
# 1                       25.541055                            17.49
# 2                       24.942066                            17.49
# 3                       25.398000                            17.49
# 4                       22.648537                            16.99
# ..                            ...                              ...
# 72                      25.971452                            17.49
# 73                      15.300714                            16.29
# 74                      24.263950                            17.49
# 75                      21.574615                            17.49
# 76                      24.378793                            17.49
#
#     menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                      24.779841                     4.4              120
# 1                      25.973858                     4.4              239
# 2                      25.930237                     4.3              122
# 3                      26.126016                     4.6              126
# 4                      23.216920                     4.5              124
# ..                           ...                     ...              ...
# 72                     25.981055                     4.3              125
# 73                     10.455384                     4.5              113
# 74                     24.884957                     4.5              120
# 75                     20.288558                     4.8              118
# 76                     24.865666                     4.5              117
#
#    number_of_ratings first  hamburger  cheeseburger  combo  specialty_item  \
# 0                     450+      15.99         17.29    NaN             NaN
# 1                     900+      15.39         16.69    NaN             NaN
# 2                        1      15.99         17.29    NaN             NaN
# 3                     600+      15.99         17.29    NaN             NaN
# 4                     250+      15.39         16.99    NaN             NaN
# ..                     ...        ...           ...    ...             ...
# 72                    210+      15.39         16.69    NaN             NaN
# 73                       1      15.99         17.29    NaN             NaN
# 74                       1      16.29         17.49    NaN             NaN
# 75                       1      15.99         17.29    NaN             NaN
# 76                    900+      15.99         17.29    NaN             NaN
#
#     fries
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 72    NaN
# 73    NaN
# 74    NaN
# 75    NaN
# 76    NaN
#
# [77 rows x 13 columns]

# %%
#TGI Fridays

ca_ff_tgi = ca_ff_[ca_ff_['restaurant_name'] == 'TGI Fridays']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_tgi = ca_ff_tgi.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_tgi.columns = [' '.join(col).strip() for col in grouped_tgi.columns.values]

# %%
#Second part of grouping 
tgi_lst = ['cheeseburger', 'seasoned fries']

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_tgi = ca_ff_tgi[ca_ff_tgi['menu_item'].isin(tgi_lst)].sort_values('menu_item')
menu_items_tgi = menu_items_tgi.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_tgi_2 = menu_items_tgi.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_tgi_2[['cheeseburger', 'fries']] = grouped_tgi_2['menu_item_price'].apply(pd.Series)
grouped_tgi_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_tgi = pd.merge(grouped_tgi, grouped_tgi_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_tgi['combo'] = np.nan
merged_tgi['specialty_item'] = np.nan
merged_tgi['hamburger'] = np.nan
merged_tgi
# Out:
#   restaurant_name                              restaurant_location  \
# 0     TGI Fridays  2795 tapo canyon rd, simi valley, ca, 93063, us
# 1     TGI Fridays         31900 dyer st, union city, ca, 94587, us
#
#    menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                      26.533507                            18.62
# 1                      26.508884                            18.62
#
#    menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                     27.678162                     4.5              140
# 1                     27.634634                     4.4              983
#
#   number_of_ratings first  cheeseburger  fries  combo  specialty_item  \
# 0                    600+         16.09   2.79    NaN             NaN
# 1                    900+         16.09   2.79    NaN             NaN
#
#    hamburger
# 0        NaN
# 1        NaN

# %%
#'Buffalo Wild Wings'
#TGI Fridays

ca_ff_buff = ca_ff_[ca_ff_['restaurant_name'] == 'Buffalo Wild Wings']

#First part of grouping 

agg_funcs = {
    'menu_item_price': [mean_non_zero, median_non_zero, std_non_zero],  # calculate the average, median, and standard dev PRICE
    'restaurant_rating': 'mean', # calculate the average RATING 
    'menu_item' : 'count',
    'number_of_ratings': 'first'
}

grouped_buff = ca_ff_buff.groupby(['restaurant_name','restaurant_location']).agg(agg_funcs).reset_index()
grouped_buff.columns = [' '.join(col).strip() for col in grouped_buff.columns.values]

# %%
#Second part of grouping 
buff_lst = ['allamerican cheeseburger', 'regular french fries']

# Filter rows where 'menu_item' contains any item in mcd_lst
menu_items_buff = ca_ff_buff[ca_ff_buff['menu_item'].isin(buff_lst)].sort_values('menu_item')
menu_items_buff = menu_items_buff.drop_duplicates(subset=['restaurant_name', 'restaurant_location', 'menu_item'])

grouped_buff_2 = menu_items_buff.groupby(['restaurant_name', 'restaurant_location'])['menu_item_price'].agg(price_list).reset_index()

grouped_buff_2[['cheeseburger', 'fries']] = grouped_buff_2['menu_item_price'].apply(pd.Series)
grouped_buff_2.drop(columns=['menu_item_price'], inplace=True)

#Merging the grouped dfs together 
merged_buff = pd.merge(grouped_buff, grouped_buff_2, on=['restaurant_name', 'restaurant_location'], how='inner')
merged_buff['combo'] = np.nan
merged_buff['specialty_item'] = np.nan
merged_buff['hamburger'] = np.nan
merged_buff
# Out:
#        restaurant_name                                restaurant_location  \
# 0   Buffalo Wild Wings          1000 s fair oaks, pasadena, ca, 91105, us
# 1   Buffalo Wild Wings                  1010 w, san marcos, ca, 92078, us
# 2   Buffalo Wild Wings          11255 e 183rd st, cerritos, ca, 90703, us
# 3   Buffalo Wild Wings       1168 galleria blvd, roseville, ca, 95678, us
# 4   Buffalo Wild Wings  12411 limonite avenue suite 650 , mira loma, e...
# ..                 ...                                                ...
# 67  Buffalo Wild Wings    795 e betteravia rd, santa maria, ca, 93454, us
# 68  Buffalo Wild Wings  8188 day creek blvd ste 140, rancho cucamonga,...
# 69  Buffalo Wild Wings        8301 on the mall, buena park, ca, 90620, us
# 70  Buffalo Wild Wings       859 blossom hill rd, san jose, ca, 95123, us
# 71  Buffalo Wild Wings  9301 tampa ave, northridge, usa, los angeles, ...
#
#     menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                       13.002329                            14.29
# 1                        8.994845                             6.99
# 2                        9.221386                             7.29
# 3                        9.026869                             7.79
# 4                       13.105352                            13.79
# ..                            ...                              ...
# 67                       7.888000                             4.74
# 68                      13.105352                            13.79
# 69                       9.482449                             8.14
# 70                       8.905155                             7.29
# 71                       9.310700                             7.54
#
#     menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                      10.266384                     4.4              109
# 1                      10.221463                     4.1              106
# 2                      10.161498                     4.0              110
# 3                       9.770446                     4.4              108
# 4                      10.118550                     4.0              108
# ..                           ...                     ...              ...
# 67                      9.943876                     4.2               98
# 68                     10.118550                     3.9              109
# 69                     10.209026                     4.3              105
# 70                     10.131247                     4.1              106
# 71                     10.235377                     4.2              107
#
#    number_of_ratings first  cheeseburger  fries  combo  specialty_item  \
# 0                        2         17.29   7.29    NaN             NaN
# 1                        1         16.79   5.99    NaN             NaN
# 2                        1         17.29   5.99    NaN             NaN
# 3                     500+         15.99   5.99    NaN             NaN
# 4                     800+         16.79   7.29    NaN             NaN
# ..                     ...           ...    ...    ...             ...
# 67                    410+         15.29   5.99    NaN             NaN
# 68                       1         16.79   7.29    NaN             NaN
# 69                    130+         16.79   7.29    NaN             NaN
# 70                    900+         16.29   5.99    NaN             NaN
# 71                       2         17.29   5.99    NaN             NaN
#
#     hamburger
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 67        NaN
# 68        NaN
# 69        NaN
# 70        NaN
# 71        NaN
#
# [72 rows x 13 columns]

# %%
#Stack all restaurants
ubereats_fullserv_prices = pd.concat([merged_outback, grouped_panera, merged_rr, merged_buff, merged_tgi, merged_apple, merged_denny]).reset_index(drop=True)

# %%
#If there are bad addresses, replace them with the actual address here 

ubereats_fullserv_prices.loc[274, 'restaurant_location'] = "1377 w foothill blvd, rialto, ca, 92376"
ubereats_fullserv_prices.loc[293, 'restaurant_location'] = "17009-a valley blvd, fontana, ca, 92335"

# %%
pattern = r",\s*([a-zA-Z]{2})\s*,?\s*(\d{5}(?:-\d{4})?)"

def extract_state_zip(address):
    match = re.search(pattern, address)
    if match:
        state, zip_code = match.groups()
        return state, zip_code
    else:
        return None, None

# Apply the function to extract state and zip code
ubereats_fullserv_prices[['state', 'zip']] = ubereats_fullserv_prices['restaurant_location'].apply(lambda x: pd.Series(extract_state_zip(x)))
ubereats_fullserv_prices['zip'] = ubereats_fullserv_prices['zip'].str.split('-').str[0].astype(int)

#Get county 
ubereats_fullserv_prices = ubereats_fullserv_prices.merge(ca_zip_count, on = 'zip')

# %%
nan_zip_rows = ubereats_fullserv_prices[ubereats_fullserv_prices['zip'].isna()]
nan_zip_rows
# Out:
#     restaurant_name                        restaurant_location  \
# 274           Denny   1377 w foothill blvd, rialto, ca, us, us
# 293           Denny  17009-a valley blvd., fontana, ca, us, us
#
#      menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 274                      11.831132                             9.76
# 293                      11.364528                             9.44
#
#      menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 274                      7.183182                     4.3              136
# 293                      6.932546                     4.4              136
#
#     number_of_ratings first  fries  cheeseburger  hamburger  combo  \
# 274                       1   5.81         17.14        NaN    NaN
# 293                    800+   5.59         16.69        NaN    NaN
#
#      specialty_item state   zip
# 274             NaN  None  None
# 293             NaN  None  None

# %%
specific_date = datetime.strptime('05142024', '%m%d%Y')
# Assign the datetime object to the entire 'date' column
ubereats_fullserv_prices['date'] = specific_date
ubereats_fullserv_prices['uber_eats'] = 1
ubereats_fullserv_prices['post_policy'] = 1
ubereats_fullserv_prices['fast_food'] = 0
ubereats_fullserv_prices['local'] = 0

# %%
#Save as csv 
ubereats_fullserv_prices.to_csv('final_processed_prices_ubereats_ca_fullserv_05142024.csv', index = True)
