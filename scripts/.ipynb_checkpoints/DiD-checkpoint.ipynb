# %%
import json
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
pre_ca = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_ca_ff_03222024.csv")
post_ca = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_processed_prices_ubereats_ca_ff_05142024.csv")

pre_nonca = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_nonca_ff_03292024.csv")
post_nonca = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_processed_prices_ubereats_nonca_ff_05162024.csv")
post_nonca['post_policy'] = 1

# %%
combined = pd.concat([pre_ca, post_ca, pre_nonca, post_nonca])

# %%
combined = combined[['restaurant_name', 'hamburger', 'cheeseburger', 'specialty_item', 'state', 'post_policy']]

# %%
combined = combined.copy()
combined['treatment'] = combined['state'].apply(lambda x: 1 if x == 'ca' else 0)
combined['interaction'] = combined['post_policy'] * combined['treatment']
combined = combined.dropna()

# %%
combined
# Out:
#       restaurant_name  hamburger  cheeseburger  specialty_item state  \
# 0            McDonald       3.49          4.39            7.89    ca
# 1         Burger King       5.39          2.79           10.29    ca
# 2            McDonald       3.89          4.39            8.29    ca
# 3            McDonald       2.95          3.04            6.46    ca
# 4     Jack in the Box       3.11          3.74            6.86    ca
# ...               ...        ...           ...             ...   ...
# 2247        Five Guys       7.91          8.87           11.63    ky
# 2248        Five Guys       9.71         11.15           13.79    pa
# 2249        Five Guys       9.23         10.55           13.55    ok
# 2250        Five Guys       9.35         10.67           13.67    tx
# 2251        Five Guys       9.35         10.67           13.67    al
#
#       post_policy  treatment  interaction
# 0               0          1            0
# 1               0          1            0
# 2               0          1            0
# 3               0          1            0
# 4               0          1            0
# ...           ...        ...          ...
# 2247            1          0            0
# 2248            1          0            0
# 2249            1          0            0
# 2250            1          0            0
# 2251            1          0            0
#
# [4912 rows x 8 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Initialize an empty dictionary to store results
results = {}

# Get unique restaurant chains
chains = combined['restaurant_name'].unique()

# List of items to analyze
items = ['hamburger', 'cheeseburger', 'specialty_item']

for chain in chains:
    # Filter data for the current chain
    chain_data = combined[combined['restaurant_name'] == chain]
    
    # Initialize dictionary to store results for each item
    results[chain] = {}
    
    for item in items:
        # Define the model for the current item
        formula = f'{item} ~ post_policy * treatment'
        model = smf.ols(formula, data=chain_data).fit()
        
        # Store the results
        results[chain][item] = model

# Print the results for each chain
for chain, chain_results in results.items():
    print(f"Results for {chain}:")
    for item, model in chain_results.items():
        print(f"  {item}:")
        print(model.summary())
        print("\n")
# Out:
# Results for McDonald:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     519.2
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          3.42e-220
# Time:                        16:20:30   Log-Likelihood:                -833.26
# No. Observations:                1275   AIC:                             1675.
# Df Residuals:                    1271   BIC:                             1695.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.4153      0.034     71.649      0.000       2.349       2.481
# post_policy              -0.0473      0.039     -1.220      0.223      -0.123       0.029
# treatment                 0.9929      0.046     21.706      0.000       0.903       1.083
# post_policy:treatment     0.1026      0.057      1.790      0.074      -0.010       0.215
# ==============================================================================
# Omnibus:                       54.192   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.411
# Skew:                           0.360   Prob(JB):                     2.84e-19
# Kurtosis:                       4.043   Cond. No.                         8.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     558.6
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          1.71e-231
# Time:                        16:20:30   Log-Likelihood:                -960.66
# No. Observations:                1275   AIC:                             1929.
# Df Residuals:                    1271   BIC:                             1950.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.7259      0.037     73.173      0.000       2.653       2.799
# post_policy              -0.0780      0.043     -1.821      0.069      -0.162       0.006
# treatment                 1.1173      0.051     22.103      0.000       1.018       1.216
# post_policy:treatment     0.1454      0.063      2.295      0.022       0.021       0.270
# ==============================================================================
# Omnibus:                       72.602   Durbin-Watson:                   1.638
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.137
# Skew:                           0.518   Prob(JB):                     1.33e-21
# Kurtosis:                       3.859   Cond. No.                         8.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     336.9
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          6.14e-161
# Time:                        16:20:30   Log-Likelihood:                -1447.6
# No. Observations:                1275   AIC:                             2903.
# Df Residuals:                    1271   BIC:                             2924.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.2348      0.055    114.236      0.000       6.128       6.342
# post_policy              -0.0610      0.063     -0.972      0.331      -0.184       0.062
# treatment                 1.2797      0.074     17.278      0.000       1.134       1.425
# post_policy:treatment     0.1614      0.093      1.739      0.082      -0.021       0.344
# ==============================================================================
# Omnibus:                      297.688   Durbin-Watson:                   1.746
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1199.464
# Skew:                           1.065   Prob(JB):                    3.46e-261
# Kurtosis:                       7.248   Cond. No.                         8.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Burger King:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     60.63
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           9.11e-36
# Time:                        16:20:30   Log-Likelihood:                -1823.6
# No. Observations:                 922   AIC:                             3655.
# Df Residuals:                     918   BIC:                             3674.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 5.3513      0.135     39.694      0.000       5.087       5.616
# post_policy              -1.3292      0.163     -8.179      0.000      -1.648      -1.010
# treatment                 0.1053      0.189      0.557      0.578      -0.266       0.476
# post_policy:treatment     1.7211      0.243      7.089      0.000       1.245       2.198
# ==============================================================================
# Omnibus:                      735.189   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12194.139
# Skew:                           3.668   Prob(JB):                         0.00
# Kurtosis:                      19.236   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     211.1
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          4.10e-104
# Time:                        16:20:30   Log-Likelihood:                -687.46
# No. Observations:                 922   AIC:                             1383.
# Df Residuals:                     918   BIC:                             1402.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.7104      0.039     68.936      0.000       2.633       2.788
# post_policy              -0.0062      0.047     -0.131      0.896      -0.099       0.087
# treatment                 0.5067      0.055      9.193      0.000       0.399       0.615
# post_policy:treatment     0.5260      0.071      7.429      0.000       0.387       0.665
# ==============================================================================
# Omnibus:                      211.908   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              567.492
# Skew:                           1.173   Prob(JB):                    5.90e-124
# Kurtosis:                       6.045   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     583.6
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          3.55e-212
# Time:                        16:20:30   Log-Likelihood:                -1248.9
# No. Observations:                 922   AIC:                             2506.
# Df Residuals:                     918   BIC:                             2525.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.6221      0.072     91.615      0.000       6.480       6.764
# post_policy               0.6222      0.087      7.141      0.000       0.451       0.793
# treatment                 2.8567      0.101     28.189      0.000       2.658       3.056
# post_policy:treatment    -0.3317      0.130     -2.548      0.011      -0.587      -0.076
# ==============================================================================
# Omnibus:                      172.215   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              621.051
# Skew:                          -0.862   Prob(JB):                    1.38e-135
# Kurtosis:                       6.632   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Jack in the Box:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     25.35
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.18e-15
# Time:                        16:20:30   Log-Likelihood:                -800.24
# No. Observations:                 780   AIC:                             1608.
# Df Residuals:                     776   BIC:                             1627.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.1084      0.065     48.171      0.000       2.982       3.235
# post_policy               0.4110      0.081      5.092      0.000       0.253       0.569
# treatment                 0.3829      0.080      4.807      0.000       0.227       0.539
# post_policy:treatment    -0.1343      0.102     -1.316      0.189      -0.335       0.066
# ==============================================================================
# Omnibus:                      461.405   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3807.847
# Skew:                           2.624   Prob(JB):                         0.00
# Kurtosis:                      12.467   Cond. No.                         8.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     57.26
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.91e-33
# Time:                        16:20:30   Log-Likelihood:                -403.30
# No. Observations:                 780   AIC:                             814.6
# Df Residuals:                     776   BIC:                             833.2
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.4888      0.039     89.938      0.000       3.413       3.565
# post_policy               0.1564      0.049      3.223      0.001       0.061       0.252
# treatment                 0.3457      0.048      7.218      0.000       0.252       0.440
# post_policy:treatment     0.0295      0.061      0.480      0.631      -0.091       0.150
# ==============================================================================
# Omnibus:                       52.793   Durbin-Watson:                   1.799
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.389
# Skew:                           0.466   Prob(JB):                     3.19e-21
# Kurtosis:                       4.426   Cond. No.                         8.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     44.44
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.65e-26
# Time:                        16:20:30   Log-Likelihood:                -1367.1
# No. Observations:                 780   AIC:                             2742.
# Df Residuals:                     776   BIC:                             2761.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 5.5729      0.133     41.753      0.000       5.311       5.835
# post_policy               0.8876      0.167      5.317      0.000       0.560       1.215
# treatment                 1.0022      0.165      6.083      0.000       0.679       1.326
# post_policy:treatment    -0.1242      0.211     -0.588      0.557      -0.539       0.290
# ==============================================================================
# Omnibus:                      439.372   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3080.085
# Skew:                           2.534   Prob(JB):                         0.00
# Kurtosis:                      11.312   Cond. No.                         8.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for The Habit:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.634
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     178.5
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           3.98e-67
# Time:                        16:20:30   Log-Likelihood:                 111.97
# No. Observations:                 313   AIC:                            -215.9
# Df Residuals:                     309   BIC:                            -201.0
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.7733      0.044    154.049      0.000       6.687       6.860
# post_policy              -0.0056      0.060     -0.093      0.926      -0.123       0.112
# treatment                 0.2557      0.046      5.530      0.000       0.165       0.347
# post_policy:treatment     0.3786      0.063      6.018      0.000       0.255       0.502
# ==============================================================================
# Omnibus:                        5.324   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                4.313
# Skew:                          -0.188   Prob(JB):                        0.116
# Kurtosis:                       2.566   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.634
# Method:                 Least Squares   F-statistic:                     181.1
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           9.25e-68
# Time:                        16:20:30   Log-Likelihood:                 112.68
# No. Observations:                 313   AIC:                            -217.4
# Df Residuals:                     309   BIC:                            -202.4
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.8933      0.044    179.930      0.000       7.807       7.980
# post_policy              -0.0056      0.059     -0.094      0.926      -0.122       0.111
# treatment                 0.2547      0.046      5.521      0.000       0.164       0.345
# post_policy:treatment     0.3815      0.063      6.077      0.000       0.258       0.505
# ==============================================================================
# Omnibus:                        4.991   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                3.997
# Skew:                          -0.172   Prob(JB):                        0.136
# Kurtosis:                       2.567   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     123.9
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.09e-52
# Time:                        16:20:30   Log-Likelihood:                -15.862
# No. Observations:                 313   AIC:                             39.72
# Df Residuals:                     309   BIC:                             54.71
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 8.8067      0.066    133.135      0.000       8.677       8.937
# post_policy              -0.0111      0.090     -0.124      0.901      -0.187       0.165
# treatment                 0.3245      0.070      4.666      0.000       0.188       0.461
# post_policy:treatment     0.4761      0.095      5.030      0.000       0.290       0.662
# ==============================================================================
# Omnibus:                       32.000   Durbin-Watson:                   2.144
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.461
# Skew:                          -0.243   Prob(JB):                      0.00197
# Kurtosis:                       2.151   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Wendy:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     165.1
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           5.06e-85
# Time:                        16:20:30   Log-Likelihood:                -453.65
# No. Observations:                 890   AIC:                             915.3
# Df Residuals:                     886   BIC:                             934.5
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.2844      0.033     69.066      0.000       2.220       2.349
# post_policy               0.0784      0.038      2.040      0.042       0.003       0.154
# treatment                 0.6107      0.047     12.875      0.000       0.518       0.704
# post_policy:treatment     0.0489      0.060      0.818      0.413      -0.068       0.166
# ==============================================================================
# Omnibus:                       29.761   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.939
# Skew:                          -0.369   Prob(JB):                     1.41e-06
# Kurtosis:                       2.573   Cond. No.                         7.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     261.5
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          1.66e-121
# Time:                        16:20:30   Log-Likelihood:                -441.48
# No. Observations:                 890   AIC:                             891.0
# Df Residuals:                     886   BIC:                             910.1
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.6912      0.033     82.484      0.000       2.627       2.755
# post_policy               0.0692      0.038      1.826      0.068      -0.005       0.144
# treatment                 0.7508      0.047     16.047      0.000       0.659       0.843
# post_policy:treatment     0.0696      0.059      1.181      0.238      -0.046       0.185
# ==============================================================================
# Omnibus:                      117.422   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              179.497
# Skew:                          -0.900   Prob(JB):                     1.05e-39
# Kurtosis:                       4.264   Cond. No.                         7.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     295.0
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):          9.81e-133
# Time:                        16:20:30   Log-Likelihood:                -877.67
# No. Observations:                 890   AIC:                             1763.
# Df Residuals:                     886   BIC:                             1783.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.8495      0.053    128.598      0.000       6.745       6.954
# post_policy               0.0123      0.062      0.198      0.843      -0.109       0.134
# treatment                 1.1654      0.076     15.256      0.000       1.015       1.315
# post_policy:treatment     0.3226      0.096      3.351      0.001       0.134       0.512
# ==============================================================================
# Omnibus:                       55.043   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.610
# Skew:                          -0.321   Prob(JB):                     7.97e-31
# Kurtosis:                       4.824   Cond. No.                         7.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Five Guys:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     225.6
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.98e-93
# Time:                        16:20:30   Log-Likelihood:                -492.72
# No. Observations:                 519   AIC:                             993.4
# Df Residuals:                     515   BIC:                             1010.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 9.0062      0.055    162.962      0.000       8.898       9.115
# post_policy               0.0749      0.072      1.043      0.298      -0.066       0.216
# treatment                 1.4416      0.083     17.286      0.000       1.278       1.605
# post_policy:treatment     0.0602      0.114      0.529      0.597      -0.163       0.284
# ==============================================================================
# Omnibus:                       63.349   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.128
# Skew:                          -0.612   Prob(JB):                     1.59e-10
# Kurtosis:                       2.232   Cond. No.                         6.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     149.6
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.01e-69
# Time:                        16:20:30   Log-Likelihood:                -593.24
# No. Observations:                 519   AIC:                             1194.
# Df Residuals:                     515   BIC:                             1211.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                10.1922      0.067    151.951      0.000      10.060      10.324
# post_policy               0.0808      0.087      0.927      0.355      -0.091       0.252
# treatment                 1.3629      0.101     13.465      0.000       1.164       1.562
# post_policy:treatment     0.1705      0.138      1.236      0.217      -0.101       0.442
# ==============================================================================
# Omnibus:                       86.312   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.435
# Skew:                          -0.501   Prob(JB):                     2.73e-09
# Kurtosis:                       2.094   Cond. No.                         6.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     146.7
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.03e-68
# Time:                        16:20:30   Log-Likelihood:                -642.42
# No. Observations:                 519   AIC:                             1293.
# Df Residuals:                     515   BIC:                             1310.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                13.0400      0.074    176.831      0.000      12.895      13.185
# post_policy               0.0829      0.096      0.865      0.388      -0.105       0.271
# treatment                 1.5056      0.111     13.530      0.000       1.287       1.724
# post_policy:treatment     0.1474      0.152      0.971      0.332      -0.151       0.445
# ==============================================================================
# Omnibus:                       80.845   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.187
# Skew:                          -0.663   Prob(JB):                     2.82e-12
# Kurtosis:                       2.163   Cond. No.                         6.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Shake Shack:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     473.5
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           3.11e-89
# Time:                        16:20:30   Log-Likelihood:                 11.958
# No. Observations:                 199   AIC:                            -15.92
# Df Residuals:                     195   BIC:                            -2.742
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.6755      0.031    247.292      0.000       7.614       7.737
# post_policy               0.0161      0.042      0.382      0.703      -0.067       0.099
# treatment                 1.2684      0.048     26.322      0.000       1.173       1.363
# post_policy:treatment    -0.0161      0.067     -0.240      0.811      -0.148       0.116
# ==============================================================================
# Omnibus:                       31.936   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.229
# Skew:                           0.656   Prob(JB):                     1.14e-19
# Kurtosis:                       5.966   Cond. No.                         6.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     451.9
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           1.68e-87
# Time:                        16:20:30   Log-Likelihood:               -0.71900
# No. Observations:                 199   AIC:                             9.438
# Df Residuals:                     195   BIC:                             22.61
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.9936      0.033    241.649      0.000       7.928       8.059
# post_policy               0.0145      0.045      0.325      0.746      -0.074       0.103
# treatment                 1.3194      0.051     25.692      0.000       1.218       1.421
# post_policy:treatment    -0.0145      0.071     -0.204      0.839      -0.155       0.126
# ==============================================================================
# Omnibus:                       47.325   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              111.687
# Skew:                           1.058   Prob(JB):                     5.59e-25
# Kurtosis:                       5.998   Cond. No.                         6.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     602.8
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           2.42e-98
# Time:                        16:20:30   Log-Likelihood:                 33.654
# No. Observations:                 199   AIC:                            -59.31
# Df Residuals:                     195   BIC:                            -46.14
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 8.2627      0.028    296.879      0.000       8.208       8.318
# post_policy               0.0121      0.038      0.322      0.748      -0.062       0.086
# treatment                 1.2811      0.043     29.649      0.000       1.196       1.366
# post_policy:treatment    -0.0121      0.060     -0.202      0.840      -0.131       0.106
# ==============================================================================
# Omnibus:                       72.535   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.768
# Skew:                           1.387   Prob(JB):                     3.61e-65
# Kurtosis:                       8.300   Cond. No.                         6.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Results for Carls Jr:
#   hamburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hamburger   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.043
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):              0.327
# Time:                        16:20:30   Log-Likelihood:                -23.409
# No. Observations:                  14   AIC:                             50.82
# Df Residuals:                      12   BIC:                             52.10
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.9900      0.984      5.072      0.000       2.847       7.133
# post_policy                    0          0        nan        nan           0           0
# treatment                 1.0850      1.063      1.021      0.327      -1.230       3.400
# post_policy:treatment          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        4.671   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                3.221
# Skew:                          -1.164   Prob(JB):                        0.200
# Kurtosis:                       2.681   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#   cheeseburger:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cheeseburger   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     25.03
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           0.000308
# Time:                        16:20:30   Log-Likelihood:                -1.6869
# No. Observations:                  14   AIC:                             7.374
# Df Residuals:                      12   BIC:                             8.652
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.9900      0.208     23.936      0.000       4.536       5.444
# post_policy                    0          0        nan        nan           0           0
# treatment                 1.1267      0.225      5.003      0.000       0.636       1.617
# post_policy:treatment          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        9.749   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                5.949
# Skew:                           1.106   Prob(JB):                       0.0511
# Kurtosis:                       5.304   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#   specialty_item:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         specialty_item   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     42.65
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):           2.81e-05
# Time:                        16:20:30   Log-Likelihood:                -6.8239
# No. Observations:                  14   AIC:                             17.65
# Df Residuals:                      12   BIC:                             18.93
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.2900      0.301     20.905      0.000       5.634       6.946
# post_policy                    0          0        nan        nan           0           0
# treatment                 2.1225      0.325      6.531      0.000       1.414       2.831
# post_policy:treatment          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       17.389   Durbin-Watson:                   2.327
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.496
# Skew:                          -1.701   Prob(JB):                     0.000432
# Kurtosis:                       6.872   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1918: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1918: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/alyssanguyen/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1918: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
summary_df = pd.DataFrame()

# Loop through each chain and each item
for chain, models in results.items():
    for item, model in models.items():
        # Append summary statistics for each item and chain
        summary_df = summary_df.append({
            'Chain': chain,
            'Item': item,
            'Coef_DiD': model.params['post_policy:treatment'],
            'StdErr_DiD': model.bse['post_policy:treatment'],
            'CI_Lower_DiD': model.conf_int().loc['post_policy:treatment'][0],
            'CI_Upper_DiD': model.conf_int().loc['post_policy:treatment'][1]
        }, ignore_index=True)


# Print the summary DataFrame
summary_df
# Out:
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# /var/folders/p9/_x396g015hb1f7h6k_mytrnc0000gn/T/ipykernel_16957/3612501037.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
#               Chain            Item  Coef_DiD  StdErr_DiD  CI_Lower_DiD  \
# 0          McDonald       hamburger  0.102637    0.057343     -0.009861
# 1          McDonald    cheeseburger  0.145402    0.063369      0.021083
# 2          McDonald  specialty_item  0.161407    0.092842     -0.020734
# 3       Burger King       hamburger  1.721051    0.242784      1.244575
# 4       Burger King    cheeseburger  0.526019    0.070805      0.387059
# 5       Burger King  specialty_item -0.331697    0.130171     -0.587164
# 6   Jack in the Box       hamburger -0.134321    0.102089     -0.334725
# 7   Jack in the Box    cheeseburger  0.029464    0.061371     -0.091009
# 8   Jack in the Box  specialty_item -0.124157    0.211165     -0.538680
# 9         The Habit       hamburger  0.378643    0.062918      0.254842
# 10        The Habit    cheeseburger  0.381513    0.062775      0.257992
# 11        The Habit  specialty_item  0.476146    0.094656      0.289894
# 12            Wendy       hamburger  0.048927    0.059784     -0.068408
# 13            Wendy    cheeseburger  0.069620    0.058972     -0.046121
# 14            Wendy  specialty_item  0.322602    0.096272      0.133655
# 15        Five Guys       hamburger  0.060198    0.113688     -0.163152
# 16        Five Guys    cheeseburger  0.170522    0.137984     -0.100558
# 17        Five Guys  specialty_item  0.147351    0.151698     -0.150672
# 18      Shake Shack       hamburger -0.016061    0.066958     -0.148115
# 19      Shake Shack    cheeseburger -0.014545    0.071362     -0.155286
# 20      Shake Shack  specialty_item -0.012121    0.060041     -0.130535
# 21         Carls Jr       hamburger  0.000000    0.000000      0.000000
# 22         Carls Jr    cheeseburger  0.000000    0.000000      0.000000
# 23         Carls Jr  specialty_item  0.000000    0.000000      0.000000
#
#     CI_Upper_DiD
# 0       0.215135
# 1       0.269722
# 2       0.343548
# 3       2.197528
# 4       0.664978
# 5      -0.076229
# 6       0.066083
# 7       0.149938
# 8       0.290366
# 9       0.502444
# 10      0.505033
# 11      0.662398
# 12      0.166263
# 13      0.185362
# 14      0.511549
# 15      0.283548
# 16      0.441602
# 17      0.445374
# 18      0.115994
# 19      0.126195
# 20      0.106292
# 21      0.000000
# 22      0.000000
# 23      0.000000

# %%
results
# Out:
# {'McDonald': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28d9910>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28d9280>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28df640>},
#  'Burger King': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28e5370>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28e9910>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28f2910>},
#  'Jack in the Box': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88d28f73a0>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881950a0>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f888819eee0>},
#  'The Habit': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881a3970>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881a8550>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881ae7f0>},
#  'Wendy': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881b8640>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881bc400>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881c24f0>},
#  'Five Guys': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881c8bb0>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88881d5a60>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88882df040>},
#  'Shake Shack': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f8888208ac0>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88882e43a0>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88e010ae50>},
#  'Carls Jr': {'hamburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88882e8c70>,
#   'cheeseburger': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88882e3f40>,
#   'specialty_item': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f88882e3670>}}

# %%
def mean_non_zero(series):
    non_zero_values = series[series != 0]
    if not non_zero_values.empty:
        mean_value = non_zero_values.mean()
        return mean_value if not np.isnan(mean_value) else 0
    else:
        return 0

#restaurants = pre_filtered['restaurant_name'].unique().tolist()

#Has Hamburger
#restaurants = ['McDonald', 'Burger King', 'Jack in the Box', 'The Habit', 'Wendy', 'Five Guys', 'Shake Shack']
restaurants = ['Outback Steakhouse', 'Applebee']



# location_ca = {
# #     'McDonald': 1221, 
# #     'Burger King': 534, 
# #     'Jack in the Box': 942, 
# #     'The Habit': 258, dd
# #     'Wendy': 294, 
# #    # 'Carls Jr': 655, 
# #     'Five Guys': 124, 
# #     'Shake Shack': 44,
# #    # 'Sonic': 82,
#     'Outback Steakhouse': 44, 
#     #'Red Robin': 57,
#     #'Denny': 389,
#     'Applebee': 106, 
#     #'Buffalo Wild Wings': 96, 
#     #'TGI Fridays': 16 
# }

location_nonca = {
#     'McDonald': 12308, 
#     'Burger King': 6193, 
#     'Jack in the Box': 1251, 
#     'The Habit': 109, 
#     'Wendy': 5728, 
# #     'Carls Jr': 2035, 
#     'Five Guys': 1346, 
#     'Shake Shack': 284,
# #     'Sonic': 3443,
    'Outback Steakhouse': 628, 
 #   'Red Robin': 438,
  #  'Denny': 1141,
    'Applebee': 1430, 
  #  'Buffalo Wild Wings': 1195, 
   # 'TGI Fridays': 212,
}


def weighted_avg(restaurants, df, locations):
    numerator = {
        'hamburger': 0,
        'cheeseburger': 0,
        'specialty_item': 0
    }
    denominator = sum(locations.values())
    
    for restaurant in restaurants:
        print(f"restaurant: {restaurant}")
        curr_df = df[df['restaurant_name'] == restaurant]
        hamburger_avg = mean_non_zero(curr_df['hamburger']) * locations[restaurant]
        cheeseburger_avg = mean_non_zero(curr_df['cheeseburger']) * locations[restaurant]
        specialty_avg = mean_non_zero(curr_df['specialty_item']) * locations[restaurant]
        
        print(f"added hamburger: {hamburger_avg}")
        print(f"added cheeseburger: {cheeseburger_avg}")
        print(f"added specialty: {specialty_avg}")
        
        numerator['hamburger'] += hamburger_avg
        numerator['cheeseburger'] += cheeseburger_avg
        numerator['specialty_item'] += specialty_avg
        print(f"hamburger: {numerator['hamburger']}")
        print(f"cheeseburger: {numerator['cheeseburger']}")
        print(f"specialty: {numerator['specialty_item']}")
        
    weighted_avg = {key: numerator[key] / denominator for key in numerator.keys()}
        
    return weighted_avg

weighted_avg(restaurants, pre_filtered, location_nonca)
