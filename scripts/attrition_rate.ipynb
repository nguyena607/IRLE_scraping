# %%
import json
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %% [markdown]
# Find additional missing restaurants

# %%
# rnd_1_bk = pd.read_csv("burger_king_missing_rnd1.csv")
# rnd_2_bk = pd.read_csv("burger_king_missing_rnd2.csv")
# combined = pd.concat([rnd_1_bk, rnd_2_bk])
combined = pd.read_csv("carlsjr_missing_rnd1.csv")

# combined['input_split'] = combined['restaurant_address'].str.split(',', 1).str[0]
# combined_filtered = combined[combined['restaurant_address'] == combined['input_split'] ]

# combined_filtered['menu_item_price'] = combined_filtered['menu_item_price'].str.replace('$', '', regex = False).astype(float)

# combined_filtered['menu_item_calories'] = combined_filtered['menu_item_calories'].str.replace(' cal', '').str.replace(',', '').astype(int)

combined_filtered = combined[['menu_item', 'menu_item_price', 'menu_item_calories', 'restaurant_address']]

# combined_filtered = combined_filtered.rename(columns = {'input_address' : 'restaurant_address'})

prev = pd.read_csv('/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/raw_prices_carlsjr_ca_05152024.csv')
combined_final = pd.concat([prev, combined_filtered ])
combined_final.to_csv("carlsjr_ca_final.csv")
combined_final
# Out:
#                                   menu_item  menu_item_price  \
# 0                 Big Angus El Diablo Combo             6.00
# 1          Hand-Crafted Strawberry Lemonade             3.80
# 2                       Single Famous Star®             7.04
# 3                       Double Famous Star®             9.55
# 4                    Big Angus Famous Star®            10.99
# ..                                      ...              ...
# 466        Big Angus Guacamole Bacon Burger             9.79
# 467                       Single El Diablo              8.79
# 468                       Double El Diablo             10.29
# 469                    Big Angus El Diablo             10.79
# 470  California Classic Double Cheeseburger             4.78
#
#      menu_item_calories                               restaurant_address
# 0                   480  871 Marina Village Pkwy, Alameda, CA, 94501, US
# 1                   270  871 Marina Village Pkwy, Alameda, CA, 94501, US
# 2                   670  871 Marina Village Pkwy, Alameda, CA, 94501, US
# 3                   920  871 Marina Village Pkwy, Alameda, CA, 94501, US
# 4                   830  871 Marina Village Pkwy, Alameda, CA, 94501, US
# ..                  ...                                              ...
# 466                 960     2903 Burgener Blvd, San Diego, CA, 92110, US
# 467                 950     2903 Burgener Blvd, San Diego, CA, 92110, US
# 468                1210     2903 Burgener Blvd, San Diego, CA, 92110, US
# 469                1050     2903 Burgener Blvd, San Diego, CA, 92110, US
# 470                 560     2903 Burgener Blvd, San Diego, CA, 92110, US
#
# [2241 rows x 4 columns]

# %%
def find_missing_restaurants(file_pairs, base_path):
    """
    This function finds the restaurants present in the first CSV file of each pair 
    but missing in the second CSV file of each pair.

    Parameters:
    file_pairs (list of tuples): List of pairs of file names.
    base_path (str): The base path where the CSV files are located.

    Returns:
    dict: A dictionary where keys are the first file names in the pairs and values are lists of missing restaurants.
    """
    missing_restaurants_ff_website = {}

    # Loop through each pair of file paths
    for file_pair in file_pairs:
        # Extract the file paths for rounds 1 and 2
        file_path_1 = base_path + file_pair[0]
        file_path_2 = base_path + file_pair[1]

        # Load the CSV files
        df_rnd_1 = pd.read_csv(file_path_1)
        df_rnd_2 = pd.read_csv(file_path_2)

        # Extract the restaurant addresses
        restaurants_rnd_1 = set(df_rnd_1['restaurant_address'])
        restaurants_rnd_2 = set(df_rnd_2['restaurant_address'])

        # Find restaurants that are in round 1 but not in round 2
        missing_restaurants = list(restaurants_rnd_1 - restaurants_rnd_2)

        # Store the missing restaurants in the dictionary
        missing_restaurants_ff_website[file_pair[0]] = missing_restaurants

    return missing_restaurants_ff_website

# Define the list of pairs of CSV files for corresponding rounds
file_pairs = [
     #("raw_prices_carlsjr_ca_03292024.csv", "carlsjr_ca_final.csv"),
    #("raw_prices_carlsjr_non_ca_03302024.csv", "raw_prices_carlsjr_non_ca_05162024.csv"),
     #("raw_prices_hardees_non_ca_03292024.csv", "raw_prices_hardees_non_ca_05162024.csv"),
]

# Define the base path where the CSV files are located
base_path = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/"

# Call the function and store the result
missing_restaurants_ff_website = find_missing_restaurants(file_pairs, base_path)

# %%
missing_restaurants_ff_website
# Out:
# {'raw_prices_hardees_non_ca_03292024.csv': ['12872 70 Business Highway West, Clayton, NC, 27520, US',
#   '2105 E Broadway Ave, Maryville, TN, 37804, US']}

# %%
test = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/raw_prices_burgerking_ca_05152024.csv")
test
# Out:
#                             menu_item  menu_item_price menu_item_calories  \
# 0                             Whopper             7.49                670
# 1                 Impossible™ Whopper             8.49                630
# 2                Texas Double Whopper             9.99              1,090
# 3                      Double Whopper             8.49                920
# 4                     Triple Whopper              9.59              1,170
# ...                               ...              ...                ...
# 3224  Fiery Buffalo Royal Crispy Wrap             3.49                360
# 3225                Royal Crispy Wrap             3.49                310
# 3226          Fiery Royal Crispy Wrap             3.49                390
# 3227  Honey Mustard Royal Crispy Wrap             3.49                290
# 3228                            Tacos             3.09                420
#
#                                  restaurant_address
# 0     1541 East 12th Street, Oakland, CA, 94606, US
# 1     1541 East 12th Street, Oakland, CA, 94606, US
# 2     1541 East 12th Street, Oakland, CA, 94606, US
# 3     1541 East 12th Street, Oakland, CA, 94606, US
# 4     1541 East 12th Street, Oakland, CA, 94606, US
# ...                                             ...
# 3224    21 West Main Street, Ventura, CA, 93001, US
# 3225    21 West Main Street, Ventura, CA, 93001, US
# 3226    21 West Main Street, Ventura, CA, 93001, US
# 3227    21 West Main Street, Ventura, CA, 93001, US
# 3228    21 West Main Street, Ventura, CA, 93001, US
#
# [3229 rows x 4 columns]

# %%
missing_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/missing_processed_smallff_06102024")
columns = missing_data.columns
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_processed_ubereats_ca_smallff_05272024.csv")[columns]
complete_data = pd.concat([missing_data, prev_data])


#Save Dataset as a csv to re-
complete_data.to_csv("final_processed_ubereats_ca_smallff_05272024.csv")
# complete_data

# %%
def find_missing_addresses(file_pairs, base_path):
    """
    This function finds the addresses of restaurants present in the first CSV file of each pair 
    but missing in the second CSV file of each pair.

    Parameters:
    file_pairs (list of tuples): List of pairs of file names.
    base_path (str): The base path where the CSV files are located.

    Returns:
    dict: A dictionary where keys are restaurant names and values are lists of missing addresses.
    """
    missing_restaurants_ubereats = {}

    # Loop through each pair of file paths
    for file_pair in file_pairs:
        # Extract the file paths for rounds 1 and 2
        file_path_1 = base_path + file_pair[0]
        file_path_2 = base_path + file_pair[1]

        # Load the CSV files
        df_rnd_1 = pd.read_csv(file_path_1)
        df_rnd_2 = pd.read_csv(file_path_2)

        # Extract the restaurant names and addresses as dictionaries
        restaurants_rnd_1 = df_rnd_1.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
        restaurants_rnd_2 = df_rnd_2.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()

        # Find missing addresses for each restaurant
        for restaurant, addresses_rnd_1 in restaurants_rnd_1.items():
            addresses_rnd_2 = restaurants_rnd_2.get(restaurant, set())
            missing_addresses = addresses_rnd_1 - addresses_rnd_2
            if missing_addresses:
                if restaurant not in missing_restaurants_ubereats:
                    missing_restaurants_ubereats[restaurant] = [] 
                missing_restaurants_ubereats[restaurant].extend(missing_addresses)
        
            # Calculate the percentage of missing addresses for the current restaurant
            total_addresses_rnd_1 = len(addresses_rnd_1)
            if total_addresses_rnd_1 != 0:
                percent_missing = (len(missing_addresses) / total_addresses_rnd_1) * 100
                print(f"Percentage of missing addresses for {restaurant}: {percent_missing:.2f}%")



    return missing_restaurants_ubereats

# Define the list of pairs of CSV files for corresponding rounds
file_pairs = [
    ("processed_prices_ubereats_ca_fflocalchains_03262024.csv", "final_processed_ubereats_ca_smallff_05272024.csv"),
]

# Define the base path where the CSV files are located
base_path = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/"

# Call the function and store the result
missing_restaurants_ubereats = find_missing_addresses(file_pairs, base_path)
missing_restaurants_ubereats
# Out:
# Percentage of missing addresses for Barney's Gourmet Hamburgers: 0.00%
# Percentage of missing addresses for Burger Lounge: 4.35%
# Percentage of missing addresses for Golden Burger: 0.00%
# Percentage of missing addresses for Gott's Roadside: 0.00%
# Percentage of missing addresses for Juicy Burger: 0.00%
# Percentage of missing addresses for Nation's Giant Hamburgers: 4.35%
# Percentage of missing addresses for Roam Artisan Burgers: 0.00%
# Percentage of missing addresses for Super Duper Burgers: 9.09%
# {'Burger Lounge': ['213 arizona ave, santa monica, ca, 90401, us'],
#  "Nation's Giant Hamburgers": ['65 moraga way, orinda, ca, 94534, us'],
#  'Super Duper Burgers': ['98 mission st, san francisco, ca, 94105, us']}

# %%
file_pairs = [("raw_prices_ubereats_nonca_ff_03292024.csv", "missing_nonca.csv")]
    
# Define the base path where the CSV files are located
base_path = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/"



missing_restaurants_ubereats = find_missing_addresses(file_pairs, base_path)

# %%
# Define the list of pairs of CSV files for corresponding rounds
file_pairs = [
    ("raw_prices_wendys_ca_03302024.csv", "raw_prices_wendys_ca_05142024.csv"),
    ("raw_prices_wendys_nonca_03302024.csv", "raw_prices_wendys_nonca_05142024.csv")
]

# Initialize a dictionary to store missing restaurant names
wendys_missing = {}

# Loop through each pair of file paths
for file_pair in file_pairs:
    # Extract the file paths for rounds 1 and 2
    file_path_1 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[0]
    file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[1]

    # Load the CSV files
    df_rnd_1 = pd.read_csv(file_path_1)
    df_rnd_2 = pd.read_csv(file_path_2)

    # Extract the restaurant addresses
    restaurants_rnd_1 = set(df_rnd_1['address'])
    restaurants_rnd_2 = set(df_rnd_2['address'])

    # Find restaurants that are in round 1 but not in round 2
    missing_restaurants = list(restaurants_rnd_1 - restaurants_rnd_2)

    # Store the missing restaurants in the dictionary
    wendys_missing[file_pair[0]] = missing_restaurants

# %%
missing_restaurants
# Out:
# ['2218 Cloverdale Avenue, Winston Salem, NC, 27103, US']

# %% [markdown]
# After Re-scraping

# %%
#Combine Dataset with the missing data 
missing_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/missing_nonca_ff_rnd4.csv")
columns = missing_data.columns
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/nonca_ff_rnd3.csv")[columns]
complete_data = pd.concat([missing_data, prev_data])
complete_data['restaurant_name'] = complete_data['restaurant_name'].str.replace('Hardee', 'Hardees', case=False)
complete_data['restaurant_name'] = complete_data['restaurant_name'].str.replace('Hardeess', 'Hardees', case=False)

complete_data['restaurant_name'] = complete_data['restaurant_name'].str.replace('Hardee', 'Hardees', case=False)
complete_data['restaurant_name'] = complete_data['restaurant_name'].str.replace('Hardeess', 'Hardees', case=False)
complete_data['restaurant_name'] = complete_data['restaurant_name'].str.replace('Hardeessss', 'Hardees', case=False)



#Save Dataset as a csv to re-
complete_data.to_csv("nonca_ff_rnd4.csv")

# %%
file_pairs = [
    ("raw_prices_ubereats_nonca_ff_hardees_032920204.csv", "nonca_ff_rnd4.csv")
]

# Initialize a dictionary to store missing addresses by restaurant name
missing_restaurants_ubereats = {}

# Loop through each pair of file paths
for file_pair in file_pairs:
    # Extract the file paths for rounds 1 and 2
    file_path_1 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[0]
    file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[1]

    # Load the CSV files
    df_rnd_1 = pd.read_csv(file_path_1)
    df_rnd_2 = pd.read_csv(file_path_2, low_memory=False)
    
    # Convert the addresses to lowercase
    df_rnd_1['restaurant_location'] = df_rnd_1['restaurant_location'].str.lower()
    df_rnd_2['restaurant_location'] = df_rnd_2['restaurant_location'].str.lower()
    

    # Extract the restaurant names and addresses as dictionaries
    restaurants_rnd_1 = df_rnd_1.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    restaurants_rnd_2 = df_rnd_2.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    
    # Find missing addresses for each restaurant
    for restaurant, addresses_rnd_1 in restaurants_rnd_1.items():
        addresses_rnd_2 = restaurants_rnd_2.get(restaurant, set())
        missing_addresses = addresses_rnd_1 - addresses_rnd_2
        if missing_addresses:
            if restaurant not in missing_restaurants_ubereats:
                missing_restaurants_ubereats[restaurant] = []
            missing_restaurants_ubereats[restaurant].extend(missing_addresses)
        
        # Calculate the percentage of missing addresses for the current restaurant
        total_addresses_rnd_1 = len(addresses_rnd_1)
        if total_addresses_rnd_1 != 0:
            percent_missing = (len(missing_addresses) / total_addresses_rnd_1) * 100
            print(f"Percentage of missing addresses for {restaurant}: {percent_missing:.2f}%")

# Print the final dictionary of missing addresses
print("\nFinal dictionary of missing addresses by restaurant name:")
for restaurant, addresses in missing_restaurants_ubereats.items():
    print(f"{restaurant}: {addresses}")
# Out:
# Percentage of missing addresses for Burger King: 16.59%
# Percentage of missing addresses for Carls Jr: 31.25%
# Percentage of missing addresses for Five Guys: 20.23%
# Percentage of missing addresses for Hardees: 1.98%
# Percentage of missing addresses for Jack in the Box: 0.86%
# Percentage of missing addresses for McDonald: 2.24%
# Percentage of missing addresses for Shake Shack: 26.51%
# Percentage of missing addresses for Sonic: 33.33%
# Percentage of missing addresses for The Habit: 14.29%
# Percentage of missing addresses for Wendy: 26.58%
#
# Final dictionary of missing addresses by restaurant name:
# Burger King: ['3155 s padre island dr, corpus christi, tx, 78415, us', '17000 n rm 620, round rock, tx, 78681, us', '4535 highway 58, chattanooga, tn, 37416, us', '4905 airport blvd, austin, tx, 78751, us', '737 n. main street, layton, ut, 84041, us', '1432 s peoria ave, tulsa, ok, 74120, us', '301 west 3rd street, austin, tx, 78701, us', '3130 south memorial drive, tulsa, ok, 74145, us', '1627 university ave, lubbock, tx, 79401, us', '3980 william penn highway, monroeville, pa, 15146, us', '2011 north hillfield road, layton, ut, 84041, us', '2414 mac davis lane, lubbock, tx, 79401, us', '1680 n freedom blvd, provo, ut, 84604, us', '619 n ih 35, austin, tx, 78702, us', '2021 morgan ave, corpus christi, tx, 78405-1541, us', '1109 university ave, lubbock, tx, 79401, us', '2037 s padre island drive, corpus christi, tx, 78417, us', '1121 e palm valley blvd, round rock, tx, 78664, us', '201 e franklin st, chapel hill, nc, 27514, us', '3227 poplar ave, memphis, tn, 38111, us', '2025 north main, layton, ut, 84041, us', '493 old hickory blvd, brentwood, tn, 37027, us', '607 louis henna blvd, round rock, tx, 78664, us', '4656 browns hill rd, pittsburgh, pa, 15217, us', '1726 bluff ridge drive, syracuse, ut, 84075, us', '2701 stewart avenue s. w., atlanta, ga, 30315, us', '1702 19th st, lubbock, tx, 79401, us', '303 e oltorf st, austin, tx, 78704, us', '1313 tilghman st, allentown, pa, 18102, us', '1621 middle tennessee boulevard, murfreesboro, tn, 37130, us', '2514 sunset blvd, west columbia, sc, 29169, us', '110 north ih 35, round rock, tx, 78681, us', '4029, riverdale, ut, 84405, us', '1901 route 286, pittsburgh, pa, 15239, us', '2391 airways boulevard, memphis, tn, 38114, us', '4200 south freeway, fort worth, tx, 76115, us', '1702 memorial blvd, murfreesboro, tn, 37129, us']
# Carls Jr: ['1726 bluff ridge drive, syracuse, ut, 84075, us', '2011 north hillfield road, layton, ut, 84041, us', '4840 s yale ave, tulsa, ok, 74135, us', '737 n. main street, layton, ut, 84041, us', '4029, riverdale, ut, 84405, us']
# Five Guys: ['410 s loop 12, irving, tx, 75060, us', '17000 n rm 620, round rock, tx, 78681, us', '800 s. kings hwy, myrtle beach, sc, 29577, us', '4905 airport blvd, austin, tx, 78751, us', '301 west 3rd street, austin, tx, 78701, us', '4639 irvington, houston, tx, 77009, us', '515 s henderson st, fort worth, tx, 76104, us', '1801 durham, houston, tx, 77007, us', '3112 e berry st, fort worth, tx, 76119, us', '5445 east fwy, houston, tx, 77020, us', '801 w moreland blvd, waukesha, wi, 53188, us', '619 n ih 35, austin, tx, 78702, us', '1170 w sunset drive, waukesha, wi, 53189, us', '1025 west airport freeway, irving, tx, 75062, us', '1121 e palm valley blvd, round rock, tx, 78664, us', '201 e franklin st, chapel hill, nc, 27514, us', '3227 poplar ave, memphis, tn, 38111, us', '3701 west fwy, fort worth, tx, 76107, us', '493 old hickory blvd, brentwood, tn, 37027, us', '804 w sunset dr, waukesha, wi, 53189, us', '607 louis henna blvd, round rock, tx, 78664, us', '4115 w. airport frwy., irving, tx, 75062, us', '2030 market center, dallas, tx, 75207, us', '10802 hughes road, houston, tx, 77089, us', 'ihop, dallas, tx, 75235, us', '4656 browns hill rd, pittsburgh, pa, 15217, us', '1726 bluff ridge drive, syracuse, ut, 84075, us', '3110 w dallas st, houston, tx, 77019, us', '5406 harry hines boulevard, 150, dallas, tx, 75235, us', '1702 19th st, lubbock, tx, 79401, us', '303 e oltorf st, austin, tx, 78704, us', '2514 sunset blvd, west columbia, sc, 29169, us', '3639 westheimer rd, houston, tx, 77027, us', '4200 south freeway, fort worth, tx, 76115, us', "502 n. o'connor rd, irving, tx, 75061, us"]
# Hardees: [nan, '618 s westmoreland rd, dallas, tx, 75211, us']
# Jack in the Box: ['2085 n. highway 360, grand prairie, tx, 75050, us']
# McDonald: ['1420 eastchase pky, fort worth, tx, 76120, us', '1400 nasa rd. 1, nassau bay, tx, 77058, us', '2514 sunset blvd, west columbia, sc, 29169, us', '2940 gulf freeway, league city, tx, 77573, us', '2430 pablo kisel blvd, brownsville, tx, 78521, us', '17455 ih 35 n, schertz, tx, 78154, us', '222 arsenal road, york, pa, 17402, us', '114 greensboro rd, high point, nc, 27260, us']
# Shake Shack: ['410 s loop 12, irving, tx, 75060, us', '17000 n rm 620, round rock, tx, 78681, us', '933 north central expressway, plano, tx, 75075, us', '4639 irvington, houston, tx, 77009, us', '515 s henderson st, fort worth, tx, 76104, us', '1801 durham, houston, tx, 77007, us', '7020 coit road, plano, tx, 75025, us', '5445 east fwy, houston, tx, 77020, us', '619 n ih 35, austin, tx, 78702, us', '1025 west airport freeway, irving, tx, 75062, us', 'north valley forge road &amp; south valley forge road, lansdale, pa, 19446, us', '3701 west fwy, fort worth, tx, 76107, us', '607 louis henna blvd, round rock, tx, 78664, us', '4115 w. airport frwy., irving, tx, 75062, us', '2030 market center, dallas, tx, 75207, us', '10802 hughes road, houston, tx, 77089, us', 'ihop, dallas, tx, 75235, us', '3110 w dallas st, houston, tx, 77019, us', '5406 harry hines boulevard, 150, dallas, tx, 75235, us', '303 e oltorf st, austin, tx, 78704, us', '3639 westheimer rd, houston, tx, 77027, us', "502 n. o'connor rd, irving, tx, 75061, us"]
# Sonic: ['3155 s padre island dr, corpus christi, tx, 78415, us', '410 s loop 12, irving, tx, 75060, us', '17000 n rm 620, round rock, tx, 78681, us', '800 s. kings hwy, myrtle beach, sc, 29577, us', '4535 highway 58, chattanooga, tn, 37416, us', '4905 airport blvd, austin, tx, 78751, us', '2829 broadway st, pearland, tx, 77581, us', '933 north central expressway, plano, tx, 75075, us', '6950 n loop 1604 e, san antonio, tx, 78247, us', '5238 highway 153, hixson, tn, 37343, us', '4639 irvington, houston, tx, 77009, us', '301 west 3rd street, austin, tx, 78701, us', '201 74th avenue north, myrtle beach, sc, 29572-3832, us', '3130 south memorial drive, tulsa, ok, 74145, us', '1627 university ave, lubbock, tx, 79401, us', '515 s henderson st, fort worth, tx, 76104, us', '2815 ne green oaks blvd, grand prairie, tx, 75050, us', '3426 main st ste 102, pearland, tx, 77581, us', '2212 e main st, league city, tx, 77573, us', '1801 durham, houston, tx, 77007, us', '2414 mac davis lane, lubbock, tx, 79401, us', '7020 coit road, plano, tx, 75025, us', '2214 n collins st, arlington, tx, 76011, us', '3112 e berry st, fort worth, tx, 76119, us', '11 west center street, orem, ut, 84057, us', '5445 east fwy, houston, tx, 77020, us', '1055 s. state street, orem, ut, 84097, us', '619 n ih 35, austin, tx, 78702, us', '2021 morgan ave, corpus christi, tx, 78405-1541, us', '1109 university ave, lubbock, tx, 79401, us', '1025 west airport freeway, irving, tx, 75062, us', '1550 interstate 10 e, beaumont, tx, 77703, us', '2940 gulf freeway, league city, tx, 77573, us', '2037 s padre island drive, corpus christi, tx, 78417, us', '1121 e palm valley blvd, round rock, tx, 78664, us', '2021 cumberland avenue, knoxville, tn, 37916, us', '1040 s 11th st, beaumont, tx, 77701, us', '6425 phelan boulevard, beaumont, tx, 77706, us', '1503 w, league city, tx, 77573, us', '700 w division st, arlington, tx, 76012, us', '3701 west fwy, fort worth, tx, 76107, us', '607 louis henna blvd, round rock, tx, 78664, us', '4115 w. airport frwy., irving, tx, 75062, us', '2200 airport fwy ste 500-a, bedford, tx, 76022, us', '19212 gulf fwy, friendswood, tx, 77546, us', '2030 market center, dallas, tx, 75207, us', '10802 hughes road, houston, tx, 77089, us', '4801 ross avenue, dallas, tx, 75204, us', 'ihop, dallas, tx, 75235, us', '17220 interstate highway 35 north, schertz, tx, 78154, us', '3110 w dallas st, houston, tx, 77019, us', '1702 19th st, lubbock, tx, 79401, us', '1400 nasa rd. 1, nassau bay, tx, 77058, us', '3850 college street, beaumont, tx, 77701, us', '303 e oltorf st, austin, tx, 78704, us', '4840 s yale ave, tulsa, ok, 74135, us', '3813 north broadway, knoxville, tn, 37917, us', '110 north ih 35, round rock, tx, 78681, us', '17455 ih 35 n, schertz, tx, 78154, us', '3639 westheimer rd, houston, tx, 77027, us', '3830 college st, beaumont, tx, 77701, us', '4200 south freeway, fort worth, tx, 76115, us', '12061 fm 2154, college station, tx, 77845, us', "502 n. o'connor rd, irving, tx, 75061, us"]
# The Habit: ['2011 north hillfield road, layton, ut, 84041, us', '7266 north carolina 73, denver, nc, 28037, us', '1726 bluff ridge drive, syracuse, ut, 84075, us']
# Wendy: ['544 east ogden avenue east pointe commons ste 500, milwaukee, wi, 53202, us', '3155 s padre island dr, corpus christi, tx, 78415, us', '10210 berkeley place drive, 120, charlotte, nc, 28262, us', '9489 westport rd, louisville, ky, 40241, us', '1031 assembly st, columbia, sc, 29201, us', '1901 s 10th st, mcallen, tx, 78503, us', '4535 highway 58, chattanooga, tn, 37416, us', '933 north central expressway, plano, tx, 75075, us', '2901 airline dr, houston, tx, 77009, us', '3801 s 27th street, milwaukee, wi, 53221, us', '737 n. main street, layton, ut, 84041, us', '2001 state road, lancaster, pa, 17601, us', '4301 market st, philadelphia, pa, 19104, us', '1821 n pointe drive, durham, nc, 27705, us', '2727 highway 280, birmingham, al, 35223, us', '1627 university ave, lubbock, tx, 79401, us', '515 s henderson st, fort worth, tx, 76104, us', '2815 ne green oaks blvd, grand prairie, tx, 75050, us', '2015 antonio street, anthony, tx, 79821, us', '2011 north hillfield road, layton, ut, 84041, us', '735 s. 11th street, beaumont, tx, 77701, us', '3426 main st ste 102, pearland, tx, 77581, us', '2212 e main st, league city, tx, 77573, us', '800 forrest st nw, atlanta, ga, 30318, us', '7020 coit road, plano, tx, 75025, us', '70 s aspen ave, new deal, tx, 79350, us', '2414 mac davis lane, lubbock, tx, 79401, us', '3112 e berry st, fort worth, tx, 76119, us', '2214 n collins st, arlington, tx, 76011, us', '2825 west nolana avenue, suite 10, mcallen, tx, 78504, us', '1109 university ave, lubbock, tx, 79401, us', '6351 e. 82nd street, indianapolis, in, 46250, us', '2940 gulf freeway, league city, tx, 77573, us', '5850 gulf fwy, houston, tx, 77023, us', '201 e franklin st, chapel hill, nc, 27514, us', '3415 navigation blvd, houston, tx, 77003, us', '7221 e. admiral, tulsa, ok, 74115, us', '1503 w, league city, tx, 77573, us', '700 w division st, arlington, tx, 76012, us', '3701 west fwy, fort worth, tx, 76107, us', '2200 airport fwy ste 500-a, bedford, tx, 76022, us', '19212 gulf fwy, friendswood, tx, 77546, us', '3957 cottage hill road, mobile, al, 36693, us', '600 east ogden avenue, milwaukee, wi, 53202, us', '4656 browns hill rd, pittsburgh, pa, 15217, us', '1726 bluff ridge drive, syracuse, ut, 84075, us', '1702 19th st, lubbock, tx, 79401, us', '1400 nasa rd. 1, nassau bay, tx, 77058, us', '1821 n pointe dr, durham, nc, 27705, us', '4840 s yale ave, tulsa, ok, 74135, us', '1419 s 10th street, mcallen, tx, 78501, us', '1621 middle tennessee boulevard, murfreesboro, tn, 37130, us', '2514 sunset blvd, west columbia, sc, 29169, us', '94 e. crosstimbers st, houston, tx, 77022, us', '4200 south freeway, fort worth, tx, 76115, us', '1700 s 10th street 105, mcallen, tx, 78503, us', '1705 w. 21st street north, wichita, ks, 67203, us', '1702 memorial blvd, murfreesboro, tn, 37129, us', '1450 kenneth road, york, pa, 17408, us']

# %%
missing_restaurants_ubereats
# Out:
# {'Burger King': ['3155 s padre island dr, corpus christi, tx, 78415, us',
#   '17000 n rm 620, round rock, tx, 78681, us',
#   '810 north main street, oregon, wi, 53575, us',
#   '4535 highway 58, chattanooga, tn, 37416, us',
#   '4905 airport blvd, austin, tx, 78751, us',
#   '737 n. main street, layton, ut, 84041, us',
#   '1432 s peoria ave, tulsa, ok, 74120, us',
#   '301 west 3rd street, austin, tx, 78701, us',
#   '3130 south memorial drive, tulsa, ok, 74145, us',
#   '1627 university ave, lubbock, tx, 79401, us',
#   '3980 william penn highway, monroeville, pa, 15146, us',
#   '2011 north hillfield road, layton, ut, 84041, us',
#   '2414 mac davis lane, lubbock, tx, 79401, us',
#   '1680 n freedom blvd, provo, ut, 84604, us',
#   '619 n ih 35, austin, tx, 78702, us',
#   '2021 morgan ave, corpus christi, tx, 78405-1541, us',
#   '1109 university ave, lubbock, tx, 79401, us',
#   '2037 s padre island drive, corpus christi, tx, 78417, us',
#   '1121 e palm valley blvd, round rock, tx, 78664, us',
#   '201 e franklin st, chapel hill, nc, 27514, us',
#   '3227 poplar ave, memphis, tn, 38111, us',
#   '2025 north main, layton, ut, 84041, us',
#   '493 old hickory blvd, brentwood, tn, 37027, us',
#   '607 louis henna blvd, round rock, tx, 78664, us',
#   '4656 browns hill rd, pittsburgh, pa, 15217, us',
#   '1726 bluff ridge drive, syracuse, ut, 84075, us',
#   '2701 stewart avenue s. w., atlanta, ga, 30315, us',
#   '1702 19th st, lubbock, tx, 79401, us',
#   '303 e oltorf st, austin, tx, 78704, us',
#   '1313 tilghman st, allentown, pa, 18102, us',
#   '1621 middle tennessee boulevard, murfreesboro, tn, 37130, us',
#   '925 north frontage road, brownsville, tx, 78521, us',
#   '2514 sunset blvd, west columbia, sc, 29169, us',
#   '110 north ih 35, round rock, tx, 78681, us',
#   '4029, riverdale, ut, 84405, us',
#   '1901 route 286, pittsburgh, pa, 15239, us',
#   '2391 airways boulevard, memphis, tn, 38114, us',
#   '4200 south freeway, fort worth, tx, 76115, us',
#   '1702 memorial blvd, murfreesboro, tn, 37129, us'],
#  'Carls Jr': ['1726 bluff ridge drive, syracuse, ut, 84075, us',
#   '2011 north hillfield road, layton, ut, 84041, us',
#   '4840 s yale ave, tulsa, ok, 74135, us',
#   '737 n. main street, layton, ut, 84041, us',
#   '4029, riverdale, ut, 84405, us'],
#  'Five Guys': ['410 s loop 12, irving, tx, 75060, us',
#   '17000 n rm 620, round rock, tx, 78681, us',
#   '800 s. kings hwy, myrtle beach, sc, 29577, us',
#   '4905 airport blvd, austin, tx, 78751, us',
#   '301 west 3rd street, austin, tx, 78701, us',
#   '4639 irvington, houston, tx, 77009, us',
#   '515 s henderson st, fort worth, tx, 76104, us',
#   '1801 durham, houston, tx, 77007, us',
#   '3112 e berry st, fort worth, tx, 76119, us',
#   '5445 east fwy, houston, tx, 77020, us',
#   '801 w moreland blvd, waukesha, wi, 53188, us',
#   '619 n ih 35, austin, tx, 78702, us',
#   '1170 w sunset drive, waukesha, wi, 53189, us',
#   '1025 west airport freeway, irving, tx, 75062, us',
#   '1121 e palm valley blvd, round rock, tx, 78664, us',
#   '201 e franklin st, chapel hill, nc, 27514, us',
#   '3227 poplar ave, memphis, tn, 38111, us',
#   '3701 west fwy, fort worth, tx, 76107, us',
#   '493 old hickory blvd, brentwood, tn, 37027, us',
#   '804 w sunset dr, waukesha, wi, 53189, us',
#   '607 louis henna blvd, round rock, tx, 78664, us',
#   '4115 w. airport frwy., irving, tx, 75062, us',
#   '2030 market center, dallas, tx, 75207, us',
#   '10802 hughes road, houston, tx, 77089, us',
#   'ihop, dallas, tx, 75235, us',
#   '4656 browns hill rd, pittsburgh, pa, 15217, us',
#   '1726 bluff ridge drive, syracuse, ut, 84075, us',
#   '3110 w dallas st, houston, tx, 77019, us',
#   '5406 harry hines boulevard, 150, dallas, tx, 75235, us',
#   '1702 19th st, lubbock, tx, 79401, us',
#   '303 e oltorf st, austin, tx, 78704, us',
#   '2514 sunset blvd, west columbia, sc, 29169, us',
#   '3639 westheimer rd, houston, tx, 77027, us',
#   '4200 south freeway, fort worth, tx, 76115, us',
#   "502 n. o'connor rd, irving, tx, 75061, us"],
#  'Hardees': [nan, '618 s westmoreland rd, dallas, tx, 75211, us'],
#  'Jack in the Box': ['2085 n. highway 360, grand prairie, tx, 75050, us'],
#  'McDonald': ['1420 eastchase pky, fort worth, tx, 76120, us',
#   '1400 nasa rd. 1, nassau bay, tx, 77058, us',
#   '2514 sunset blvd, west columbia, sc, 29169, us',
#   '2940 gulf freeway, league city, tx, 77573, us',
#   '2430 pablo kisel blvd, brownsville, tx, 78521, us',
#   '17455 ih 35 n, schertz, tx, 78154, us',
#   '222 arsenal road, york, pa, 17402, us',
#   '114 greensboro rd, high point, nc, 27260, us'],
#  'Shake Shack': ['410 s loop 12, irving, tx, 75060, us',
#   '17000 n rm 620, round rock, tx, 78681, us',
#   '933 north central expressway, plano, tx, 75075, us',
#   '4639 irvington, houston, tx, 77009, us',
#   '515 s henderson st, fort worth, tx, 76104, us',
#   '1801 durham, houston, tx, 77007, us',
#   '7020 coit road, plano, tx, 75025, us',
#   '5445 east fwy, houston, tx, 77020, us',
#   '619 n ih 35, austin, tx, 78702, us',
#   '1025 west airport freeway, irving, tx, 75062, us',
#   'north valley forge road &amp; south valley forge road, lansdale, pa, 19446, us',
#   '3701 west fwy, fort worth, tx, 76107, us',
#   '607 louis henna blvd, round rock, tx, 78664, us',
#   '4115 w. airport frwy., irving, tx, 75062, us',
#   '2030 market center, dallas, tx, 75207, us',
#   '10802 hughes road, houston, tx, 77089, us',
#   'ihop, dallas, tx, 75235, us',
#   '3110 w dallas st, houston, tx, 77019, us',
#   '5406 harry hines boulevard, 150, dallas, tx, 75235, us',
#   '303 e oltorf st, austin, tx, 78704, us',
#   '3639 westheimer rd, houston, tx, 77027, us',
#   "502 n. o'connor rd, irving, tx, 75061, us"],
#  'Sonic': ['3155 s padre island dr, corpus christi, tx, 78415, us',
#   '410 s loop 12, irving, tx, 75060, us',
#   '17000 n rm 620, round rock, tx, 78681, us',
#   '800 s. kings hwy, myrtle beach, sc, 29577, us',
#   '4535 highway 58, chattanooga, tn, 37416, us',
#   '850 crossings boulevard, morgantown, pa, 19520, us',
#   '2829 broadway st, pearland, tx, 77581, us',
#   '933 north central expressway, plano, tx, 75075, us',
#   '6950 n loop 1604 e, san antonio, tx, 78247, us',
#   '4905 airport blvd, austin, tx, 78751, us',
#   '5238 highway 153, hixson, tn, 37343, us',
#   '4639 irvington, houston, tx, 77009, us',
#   '301 west 3rd street, austin, tx, 78701, us',
#   '201 74th avenue north, myrtle beach, sc, 29572-3832, us',
#   '3130 south memorial drive, tulsa, ok, 74145, us',
#   '1627 university ave, lubbock, tx, 79401, us',
#   '515 s henderson st, fort worth, tx, 76104, us',
#   '2815 ne green oaks blvd, grand prairie, tx, 75050, us',
#   '3426 main st ste 102, pearland, tx, 77581, us',
#   '2212 e main st, league city, tx, 77573, us',
#   '1801 durham, houston, tx, 77007, us',
#   '2414 mac davis lane, lubbock, tx, 79401, us',
#   '7020 coit road, plano, tx, 75025, us',
#   '2214 n collins st, arlington, tx, 76011, us',
#   '3112 e berry st, fort worth, tx, 76119, us',
#   '11 west center street, orem, ut, 84057, us',
#   '5445 east fwy, houston, tx, 77020, us',
#   '1055 s. state street, orem, ut, 84097, us',
#   '619 n ih 35, austin, tx, 78702, us',
#   '2021 morgan ave, corpus christi, tx, 78405-1541, us',
#   '1109 university ave, lubbock, tx, 79401, us',
#   '1025 west airport freeway, irving, tx, 75062, us',
#   '1550 interstate 10 e, beaumont, tx, 77703, us',
#   '2940 gulf freeway, league city, tx, 77573, us',
#   '2037 s padre island drive, corpus christi, tx, 78417, us',
#   '1121 e palm valley blvd, round rock, tx, 78664, us',
#   '2021 cumberland avenue, knoxville, tn, 37916, us',
#   '1040 s 11th st, beaumont, tx, 77701, us',
#   '6425 phelan boulevard, beaumont, tx, 77706, us',
#   '1503 w, league city, tx, 77573, us',
#   '700 w division st, arlington, tx, 76012, us',
#   '3701 west fwy, fort worth, tx, 76107, us',
#   '607 louis henna blvd, round rock, tx, 78664, us',
#   '4115 w. airport frwy., irving, tx, 75062, us',
#   '2200 airport fwy ste 500-a, bedford, tx, 76022, us',
#   '19212 gulf fwy, friendswood, tx, 77546, us',
#   '2030 market center, dallas, tx, 75207, us',
#   '10802 hughes road, houston, tx, 77089, us',
#   '4801 ross avenue, dallas, tx, 75204, us',
#   'ihop, dallas, tx, 75235, us',
#   '17220 interstate highway 35 north, schertz, tx, 78154, us',
#   '3110 w dallas st, houston, tx, 77019, us',
#   '1702 19th st, lubbock, tx, 79401, us',
#   '1400 nasa rd. 1, nassau bay, tx, 77058, us',
#   '3850 college street, beaumont, tx, 77701, us',
#   '303 e oltorf st, austin, tx, 78704, us',
#   '4840 s yale ave, tulsa, ok, 74135, us',
#   '3813 north broadway, knoxville, tn, 37917, us',
#   '110 north ih 35, round rock, tx, 78681, us',
#   '17455 ih 35 n, schertz, tx, 78154, us',
#   '3639 westheimer rd, houston, tx, 77027, us',
#   '3830 college st, beaumont, tx, 77701, us',
#   '4200 south freeway, fort worth, tx, 76115, us',
#   '12061 fm 2154, college station, tx, 77845, us',
#   "502 n. o'connor rd, irving, tx, 75061, us"],
#  'The Habit': ['2011 north hillfield road, layton, ut, 84041, us',
#   '7266 north carolina 73, denver, nc, 28037, us',
#   '1726 bluff ridge drive, syracuse, ut, 84075, us'],
#  'Wendy': ['544 east ogden avenue east pointe commons ste 500, milwaukee, wi, 53202, us',
#   '3155 s padre island dr, corpus christi, tx, 78415, us',
#   '10210 berkeley place drive, 120, charlotte, nc, 28262, us',
#   '9489 westport rd, louisville, ky, 40241, us',
#   '1031 assembly st, columbia, sc, 29201, us',
#   '1901 s 10th st, mcallen, tx, 78503, us',
#   '4535 highway 58, chattanooga, tn, 37416, us',
#   '933 north central expressway, plano, tx, 75075, us',
#   '2901 airline dr, houston, tx, 77009, us',
#   '3801 s 27th street, milwaukee, wi, 53221, us',
#   '737 n. main street, layton, ut, 84041, us',
#   '2001 state road, lancaster, pa, 17601, us',
#   '4301 market st, philadelphia, pa, 19104, us',
#   '1821 n pointe drive, durham, nc, 27705, us',
#   '2727 highway 280, birmingham, al, 35223, us',
#   '1627 university ave, lubbock, tx, 79401, us',
#   '515 s henderson st, fort worth, tx, 76104, us',
#   '2815 ne green oaks blvd, grand prairie, tx, 75050, us',
#   '2015 antonio street, anthony, tx, 79821, us',
#   '2011 north hillfield road, layton, ut, 84041, us',
#   '735 s. 11th street, beaumont, tx, 77701, us',
#   '3426 main st ste 102, pearland, tx, 77581, us',
#   '13211 hwy 90, boutte, la, 70039, us',
#   '2212 e main st, league city, tx, 77573, us',
#   '800 forrest st nw, atlanta, ga, 30318, us',
#   '7020 coit road, plano, tx, 75025, us',
#   '70 s aspen ave, new deal, tx, 79350, us',
#   '2414 mac davis lane, lubbock, tx, 79401, us',
#   '3112 e berry st, fort worth, tx, 76119, us',
#   '2214 n collins st, arlington, tx, 76011, us',
#   '2825 west nolana avenue, suite 10, mcallen, tx, 78504, us',
#   '1109 university ave, lubbock, tx, 79401, us',
#   '6351 e. 82nd street, indianapolis, in, 46250, us',
#   '2940 gulf freeway, league city, tx, 77573, us',
#   '5850 gulf fwy, houston, tx, 77023, us',
#   '201 e franklin st, chapel hill, nc, 27514, us',
#   '3415 navigation blvd, houston, tx, 77003, us',
#   '7221 e. admiral, tulsa, ok, 74115, us',
#   '1503 w, league city, tx, 77573, us',
#   '700 w division st, arlington, tx, 76012, us',
#   '3701 west fwy, fort worth, tx, 76107, us',
#   '2200 airport fwy ste 500-a, bedford, tx, 76022, us',
#   '19212 gulf fwy, friendswood, tx, 77546, us',
#   '3957 cottage hill road, mobile, al, 36693, us',
#   '600 east ogden avenue, milwaukee, wi, 53202, us',
#   '4656 browns hill rd, pittsburgh, pa, 15217, us',
#   '1726 bluff ridge drive, syracuse, ut, 84075, us',
#   '1702 19th st, lubbock, tx, 79401, us',
#   '1400 nasa rd. 1, nassau bay, tx, 77058, us',
#   '1821 n pointe dr, durham, nc, 27705, us',
#   '4840 s yale ave, tulsa, ok, 74135, us',
#   '1419 s 10th street, mcallen, tx, 78501, us',
#   '1621 middle tennessee boulevard, murfreesboro, tn, 37130, us',
#   '2514 sunset blvd, west columbia, sc, 29169, us',
#   '94 e. crosstimbers st, houston, tx, 77022, us',
#   '4200 south freeway, fort worth, tx, 76115, us',
#   '1700 s 10th street 105, mcallen, tx, 78503, us',
#   '1705 w. 21st street north, wichita, ks, 67203, us',
#   '1702 memorial blvd, murfreesboro, tn, 37129, us',
#   '1450 kenneth road, york, pa, 17408, us']}

# %% [markdown]
# Full Service

# %%
rr = pd.read_csv("missing_redrobin.csv")
applebee = pd.read_csv("missing_applebee.csv")
bjs = pd.read_csv("missing_bjs.csv")
buffalo = pd.read_csv("missing_buffalo.csv")
chilis = pd.read_csv("missing_chilis.csv")
dennys = pd.read_csv("missing_dennys.csv")
outback = pd.read_csv("missing_outback.csv")
panera = pd.read_csv("missing_panera.csv")
tgif = pd.read_csv("missing_tgif.csv")


fullserv = pd.concat([rr, applebee, bjs, buffalo, chilis, dennys, outback, panera, tgif]).dropna()
fullserv

ca_fullserv = fullserv[fullserv['restaurant_location'].str.contains(', CA,')]
nonca_fullserv = fullserv[~fullserv['restaurant_location'].str.contains(', CA,')]

ca_fullserv.to_csv("missing_ca_fullserv_rnd1.csv", index = False)
nonca_fullserv.to_csv("missing_nonca_fullserv_rnd1.csv", index = False)

# %% [markdown]
# CA FullServ

# %%
#Add missing to corresponding 
#Combine Dataset with the missing data 
missing_data = pd.read_csv("missing_ca_fullserv_rnd2.csv")
columns = missing_data.columns
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/ca_fullserv_rnd1.csv")[columns]
complete_data = pd.concat([missing_data, prev_data])


#Save Dataset as a csv to re-
complete_data.to_csv("final_ca_fullserv.csv")
#complete_data
complete_data['restaurant_name'].unique()
# Out:
# array(['BJs Restaurants', 'TGI Fridays', 'Red Robin', 'Applebee', 'BJ',
#        'Buffalo Wild Wings', "Chili's", 'Denny', 'Outback Steakhouse',
#        'Panera Bread', 'TGI Friday'], dtype=object)

# %% [markdown]
# NONCA

# %%
file_pairs = [
    ("raw_prices_ubereats_ca_fullserv_03252024.csv", "ca_fullserv_rnd2.csv")
]

# Initialize a dictionary to store missing addresses by restaurant name
missing_restaurants_ubereats = {}

# Loop through each pair of file paths
for file_pair in file_pairs:
    # Extract the file paths for rounds 1 and 2
    file_path_1 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[0]
    file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[1]

    # Load the CSV files
    df_rnd_1 = pd.read_csv(file_path_1)
    df_rnd_2 = pd.read_csv(file_path_2, low_memory=False)
    
    # Convert the addresses to lowercase
    df_rnd_1['restaurant_location'] = df_rnd_1['restaurant_location'].str.lower()
    df_rnd_2['restaurant_location'] = df_rnd_2['restaurant_location'].str.lower()
    
    #
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace('BJ', "BJ's Restaurants", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("Chili's", "Chili's Grill & Bar", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("TGI Friday", "TGI Fridays", case=False)




    # Extract the restaurant names and addresses as dictionaries
    restaurants_rnd_1 = df_rnd_1.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    restaurants_rnd_2 = df_rnd_2.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    
    # Find missing addresses for each restaurant
    for restaurant, addresses_rnd_1 in restaurants_rnd_1.items():
        addresses_rnd_2 = restaurants_rnd_2.get(restaurant, set())
        missing_addresses = addresses_rnd_1 - addresses_rnd_2
        if missing_addresses:
            if restaurant not in missing_restaurants_ubereats:
                missing_restaurants_ubereats[restaurant] = []
            missing_restaurants_ubereats[restaurant].extend(missing_addresses)
        
        # Calculate the percentage of missing addresses for the current restaurant
        total_addresses_rnd_1 = len(addresses_rnd_1)
        if total_addresses_rnd_1 != 0:
            percent_missing = (len(missing_addresses) / total_addresses_rnd_1) * 100
            print(f"Percentage of missing addresses for {restaurant}: {percent_missing:.2f}%")

# Print the final dictionary of missing addresses
print("\nFinal dictionary of missing addresses by restaurant name:")
for restaurant, addresses in missing_restaurants_ubereats.items():
    print(f"{restaurant}: {addresses}")
# Out:
# Percentage of missing addresses for Applebee: 2.56%
# Percentage of missing addresses for BJ's Restaurants: 15.91%
# Percentage of missing addresses for Buffalo Wild Wings: 1.39%
# Percentage of missing addresses for Chili's Grill & Bar: 5.66%
# Percentage of missing addresses for Denny: 0.00%
# Percentage of missing addresses for Outback Steakhouse: 0.00%
# Percentage of missing addresses for Panera Bread: 0.00%
# Percentage of missing addresses for Red Robin: 0.00%
# Percentage of missing addresses for TGI Fridays: 12.50%
#
# Final dictionary of missing addresses by restaurant name:
# Applebee: ['9105 e stockton blvd, elk grove, ca, 95624, us', '9255 winnetka ave, chatsworth, ca, 91311, us']
# BJ's Restaurants: ['1200, roseville, ca, 95678, us', '460 the city drive s, orange, ca, 92868, us', '2730 e. bidwell street, folsom, ca, 95630, us', '9237 laguna springs drive, elk grove, ca, 95758, us', '13130 jamboree road, irvine, ca, 92602, us', '3531 n. freeway blvd., sacramento, ca, 95834, us', '1689 arden way, sacramento, ca, 95815, us']
# Buffalo Wild Wings: ['3525 w carson st, ste 163, torrance, ca, 90503, us']
# Chili's Grill & Bar: [nan, '543 coleman avenue, san jose, ca, 95110-2047, us', '3591 el camino real, santa clara, ca, 95051-2123, us']
# TGI Fridays: ['31900 dyer st, union city, ca, 94587, us']

# %%
#Add missing to corresponding 
#Combine Dataset with the missing data 
missing_data = pd.read_csv("missing_nonca_fullserv_rnd3.csv")
columns = missing_data.columns
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/nonca_fullserv_rnd2.csv")[columns]
complete_data = pd.concat([missing_data, prev_data])


#Save Dataset as a csv to re-
complete_data.to_csv("nonca_fullserv_rnd3.csv")
complete_data
# Out:
#         Unnamed: 0 restaurant_name                 menu_item  menu_item_price  \
# 0                0          Chilis            Triple Dipper®            18.59
# 1                1          Chilis     Southwestern Eggrolls            14.59
# 2                2          Chilis             Skillet Queso            12.09
# 3                3          Chilis            Boneless Wings             0.00
# 4                4          Chilis       White Skillet Queso             9.99
# ...            ...             ...                       ...              ...
# 132728       89065       Red Robin                  Coleslaw             4.79
# 132729       89066       Red Robin              Garlic Fries             4.79
# 132730       89067       Red Robin               Yukon Chips             3.59
# 132731       89068       Red Robin  Garlic Parmesan Broccoli             4.79
# 132732       89069       Red Robin          Steamed Broccoli             3.59
#
#                                       restaurant_location  \
# 0       4600 Chapel Hill Blvd., Durham, NC, 27707-2669...
# 1       4600 Chapel Hill Blvd., Durham, NC, 27707-2669...
# 2       4600 Chapel Hill Blvd., Durham, NC, 27707-2669...
# 3       4600 Chapel Hill Blvd., Durham, NC, 27707-2669...
# 4       4600 Chapel Hill Blvd., Durham, NC, 27707-2669...
# ...                                                   ...
# 132728        95 N Moorland Rd, Brookfield, WI, 53005, US
# 132729        95 N Moorland Rd, Brookfield, WI, 53005, US
# 132730        95 N Moorland Rd, Brookfield, WI, 53005, US
# 132731        95 N Moorland Rd, Brookfield, WI, 53005, US
# 132732        95 N Moorland Rd, Brookfield, WI, 53005, US
#
#                                         inputted_location  restaurant_rating  \
# 0       6917 fayetteville rd., durham, nc, 27713-8723, us                4.2
# 1       6917 fayetteville rd., durham, nc, 27713-8723, us                4.2
# 2       6917 fayetteville rd., durham, nc, 27713-8723, us                4.2
# 3       6917 fayetteville rd., durham, nc, 27713-8723, us                4.2
# 4       6917 fayetteville rd., durham, nc, 27713-8723, us                4.2
# ...                                                   ...                ...
# 132728  Waukesha Village Hall W250 S3567 Center Road W...                4.4
# 132729  Waukesha Village Hall W250 S3567 Center Road W...                4.4
# 132730  Waukesha Village Hall W250 S3567 Center Road W...                4.4
# 132731  Waukesha Village Hall W250 S3567 Center Road W...                4.4
# 132732  Waukesha Village Hall W250 S3567 Center Road W...                4.4
#
#        number_of_ratings restaurant_distance
# 0                   700+              4.6 mi
# 1                   700+              4.6 mi
# 2                   700+              4.6 mi
# 3                   700+              4.6 mi
# 4                   700+              4.6 mi
# ...                  ...                 ...
# 132728              470+                8 mi
# 132729              470+                8 mi
# 132730              470+                8 mi
# 132731              470+                8 mi
# 132732              470+                8 mi
#
# [137779 rows x 9 columns]

# %%
file_pairs = [
    ("raw_prices_ubereats_nonca_fullserv_03252024.csv", "nonca_fullserv_rnd3.csv")
]

# Initialize a dictionary to store missing addresses by restaurant name
missing_restaurants_ubereats = {}

# Loop through each pair of file paths
for file_pair in file_pairs:
    # Extract the file paths for rounds 1 and 2
    file_path_1 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[0]
    file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[1]

    # Load the CSV files
    df_rnd_1 = pd.read_csv(file_path_1)
    df_rnd_2 = pd.read_csv(file_path_2, low_memory=False)
    
    # Convert the addresses to lowercase
    df_rnd_1['restaurant_location'] = df_rnd_1['restaurant_location'].str.lower()
    df_rnd_2['restaurant_location'] = df_rnd_2['restaurant_location'].str.lower()
    
    #Replace Restaurant Names
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace('BJ', "BJ's Restaurants", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("Chili's", "Chili's Grill & Bar", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("TGI Friday", "TGI Fridays", case=False)




    # Extract the restaurant names and addresses as dictionaries
    restaurants_rnd_1 = df_rnd_1.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    restaurants_rnd_2 = df_rnd_2.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    
    # Find missing addresses for each restaurant
    for restaurant, addresses_rnd_1 in restaurants_rnd_1.items():
        addresses_rnd_2 = restaurants_rnd_2.get(restaurant, set())
        missing_addresses = addresses_rnd_1 - addresses_rnd_2
        if missing_addresses:
            if restaurant not in missing_restaurants_ubereats:
                missing_restaurants_ubereats[restaurant] = []
            missing_restaurants_ubereats[restaurant].extend(missing_addresses)
        
        # Calculate the percentage of missing addresses for the current restaurant
        total_addresses_rnd_1 = len(addresses_rnd_1)
        if total_addresses_rnd_1 != 0:
            percent_missing = (len(missing_addresses) / total_addresses_rnd_1) * 100
            print(f"Percentage of missing addresses for {restaurant}: {percent_missing:.2f}%")

# Print the final dictionary of missing addresses
print("\nFinal dictionary of missing addresses by restaurant name:")
for restaurant, addresses in missing_restaurants_ubereats.items():
    print(f"{restaurant}: {addresses}")
# Out:
# Percentage of missing addresses for Applebee: 3.95%
# Percentage of missing addresses for BJ's Restaurants: 7.41%
# Percentage of missing addresses for Buffalo Wild Wings: 4.40%
# Percentage of missing addresses for Chili's Grill & Bar: 13.10%
# Percentage of missing addresses for Denny: 3.36%
# Percentage of missing addresses for Outback Steakhouse: 0.00%
# Percentage of missing addresses for Panera Bread: 0.00%
# Percentage of missing addresses for Red Robin: 0.00%
# Percentage of missing addresses for TGI Fridays: 70.73%
#
# Final dictionary of missing addresses by restaurant name:
# Applebee: ['24041 southland dr, hayward, ca, 94545, us', '4353 lawrenceville hwy., tucker, ga, 30084, us', '4808, dublin, ca, 94568, us', '1041 admiral callaghan lane, vallejo, ca, 94591, us', '5010 w hwy 290 service rd, austin, tx, 78735, us', '614 north valley mills, waco, tx, 76710, us']
# BJ's Restaurants: ['515 w. bay area boulevard, webster, tx, 77598, us', '3620 fallon road, dublin, ca, 94568, us']
# Buffalo Wild Wings: ['3712, dublin, ca, 94568, us', '7604 n i-35, austin, tx, 78752, us', '2720 north grandview boulevard, waukesha, wi, 53188, us', '4415 ambassador caffery pkwy ste 700, lafayette, la, 70508, us', '32135 union lndg, union city, ca, 94587, us', '5b serramonte center serramonte center, daly city, ca, 94015, us', '2315 w interstate 20, grand prairie, tx, 75052, us']
# Chili's Grill & Bar: ['6917 fayetteville rd., durham, nc, 27713-8723, us', '4111 roswell road ne., marietta, ga, 30062-6242, us', '108 marketplace drive, lexington, ky, 40503-4414, us', '4145, austell, ga, 30106-1836, us', '940 east lewis &amp; clark pkwy., clarksville, in, 47129-2214, us', '8665 memorial blvd., port arthur, tx, 77640-7014, us', '11720 medlock bridge rd., johns creek, ga, 30097-1509, us', '6536, lake worth, tx, 76135-3002, us', '7800 n. point parkway, alpharetta, ga, 30022-3004, us', '1615 millerville rd., baton rouge, la, 70816-1347, us', '14570 forum pkwy, selma, tx, 78154-1306, us']
# Denny: ['991 n 400 w, layton, ut, 84041, us', '1313 willow pass rd, concord, ca, 94520, us', '1803 marina blvd, san leandro, ca, 94577, us', '3155 e. fairview avenue, meridian, id, 83642, us', '607 avenue q, lubbock, tx, 79401, us']
# TGI Fridays: ['2800 oxford dr, bethel park, pa, 15102, us', '15190 crossroads pkwy, gulfport, ms, 39503, us', '6840 northlake mall drive, charlotte, nc, 28216, us', '1835 n highway 17, mount pleasant, sc, 29464, us', '301 rocky run pkwy, wilmington, de, 19803, us', '1100 timber dr e, garner, nc, 27529, us', '240 mall blvd, monroeville, pa, 15146, us', '2871 stonecrest cir, lithonia, ga, 30038, us', '1114 woodruff road, greenville, sc, 29607, us', '20430 highway 59 n, humble, tx, us, us', '3502 e 86th st, indianapolis, in, 46240, us', '3202 s highway 17, murrells inlet, sc, 29576, us', '1516 s willow st, manchester, nh, 03103, us', '2794 parkway, pigeon forge, tn, 37863, us', '6915 w 38th st, indianapolis, in, 46214, us', '3700 towne crossing blvd, mesquite, tx, 75150, us', '12811 s tryon st, charlotte, nc, us, us', '703 41, schererville, in, 46375, us', '395 s cedar crest blvd, allentown, pa, 18103, us', '3670 camp creek parkway, atlanta, ga, 30331, us', '449 opry mills dr, nashville, tn, 37214, us', '4951 belt line rd, dallas, tx, 75001, us', '4239 nw expressway st, oklahoma city, ok, 73116, us', '4423 w wendover ave, greensboro, nc, 27407, us', '409 w wt harris blvd, charlotte, nc, 28262, us', '311 north clark road, cedar hill, tx, 75104, us', '115 hendersonvile rd, asheville, nc, 28803, us', '4000 city ave, philadelphia, pa, 19131, us', '2502 e springs dr, madison, wi, 53704, us']

# %%
missing_restaurants_ubereats
# Out:
# {'Applebee': ['24041 southland dr, hayward, ca, 94545, us',
#   '4353 lawrenceville hwy., tucker, ga, 30084, us',
#   '4808, dublin, ca, 94568, us',
#   '1041 admiral callaghan lane, vallejo, ca, 94591, us',
#   '5010 w hwy 290 service rd, austin, tx, 78735, us',
#   '614 north valley mills, waco, tx, 76710, us'],
#  "BJ's Restaurants": ['515 w. bay area boulevard, webster, tx, 77598, us',
#   '3620 fallon road, dublin, ca, 94568, us'],
#  'Buffalo Wild Wings': ['3712, dublin, ca, 94568, us',
#   '7604 n i-35, austin, tx, 78752, us',
#   '2720 north grandview boulevard, waukesha, wi, 53188, us',
#   '4415 ambassador caffery pkwy ste 700, lafayette, la, 70508, us',
#   '32135 union lndg, union city, ca, 94587, us',
#   '5b serramonte center serramonte center, daly city, ca, 94015, us',
#   '2315 w interstate 20, grand prairie, tx, 75052, us'],
#  "Chili's Grill & Bar": ['6917 fayetteville rd., durham, nc, 27713-8723, us',
#   '4111 roswell road ne., marietta, ga, 30062-6242, us',
#   '108 marketplace drive, lexington, ky, 40503-4414, us',
#   '4145, austell, ga, 30106-1836, us',
#   '940 east lewis &amp; clark pkwy., clarksville, in, 47129-2214, us',
#   '8665 memorial blvd., port arthur, tx, 77640-7014, us',
#   '11720 medlock bridge rd., johns creek, ga, 30097-1509, us',
#   '6536, lake worth, tx, 76135-3002, us',
#   '7800 n. point parkway, alpharetta, ga, 30022-3004, us',
#   '1615 millerville rd., baton rouge, la, 70816-1347, us',
#   '14570 forum pkwy, selma, tx, 78154-1306, us'],
#  'Denny': ['991 n 400 w, layton, ut, 84041, us',
#   '1313 willow pass rd, concord, ca, 94520, us',
#   '1803 marina blvd, san leandro, ca, 94577, us',
#   '3155 e. fairview avenue, meridian, id, 83642, us',
#   '607 avenue q, lubbock, tx, 79401, us'],
#  'TGI Fridays': ['2800 oxford dr, bethel park, pa, 15102, us',
#   '15190 crossroads pkwy, gulfport, ms, 39503, us',
#   '6840 northlake mall drive, charlotte, nc, 28216, us',
#   '1835 n highway 17, mount pleasant, sc, 29464, us',
#   '301 rocky run pkwy, wilmington, de, 19803, us',
#   '1100 timber dr e, garner, nc, 27529, us',
#   '240 mall blvd, monroeville, pa, 15146, us',
#   '2871 stonecrest cir, lithonia, ga, 30038, us',
#   '1114 woodruff road, greenville, sc, 29607, us',
#   '20430 highway 59 n, humble, tx, us, us',
#   '3502 e 86th st, indianapolis, in, 46240, us',
#   '3202 s highway 17, murrells inlet, sc, 29576, us',
#   '1516 s willow st, manchester, nh, 03103, us',
#   '2794 parkway, pigeon forge, tn, 37863, us',
#   '6915 w 38th st, indianapolis, in, 46214, us',
#   '3700 towne crossing blvd, mesquite, tx, 75150, us',
#   '12811 s tryon st, charlotte, nc, us, us',
#   '703 41, schererville, in, 46375, us',
#   '395 s cedar crest blvd, allentown, pa, 18103, us',
#   '3670 camp creek parkway, atlanta, ga, 30331, us',
#   '449 opry mills dr, nashville, tn, 37214, us',
#   '4951 belt line rd, dallas, tx, 75001, us',
#   '4239 nw expressway st, oklahoma city, ok, 73116, us',
#   '4423 w wendover ave, greensboro, nc, 27407, us',
#   '409 w wt harris blvd, charlotte, nc, 28262, us',
#   '311 north clark road, cedar hill, tx, 75104, us',
#   '115 hendersonvile rd, asheville, nc, 28803, us',
#   '4000 city ave, philadelphia, pa, 19131, us',
#   '2502 e springs dr, madison, wi, 53704, us']}

# %%
#Add missing to corresponding 
#Combine Dataset with the missing data 
missing_data = pd.read_csv("missing_ca_localff.csv")
columns = missing_data.columns
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/raw_prices_ubereats_ca_fflocal05272024.csv")[columns]
complete_data = pd.concat([missing_data, prev_data])


#Save Dataset as a csv to re-
complete_data.to_csv("final_ca_localff.csv")
# complete_data

complete_data
# Out:
#       Unnamed: 0 restaurant_name                       menu_item  \
# 0              0  Burger Station            Veggie Delight Salad
# 1              1  Burger Station            Chicken Caesar Salad
# 2              2  Burger Station                     Green Salad
# 3              3  Burger Station                    Chef's Salad
# 4              4  Burger Station                  Oriental Salad
# ...          ...             ...                             ...
# 9331        9331       R Burgers           Buffalo Dipping Sauce
# 9332        9332       R Burgers     Honey Mustard Dipping Sauce
# 9333        9333       R Burgers             Ranch Dipping Sauce
# 9334        9334       R Burgers  Sweet &amp; Sour Dipping Sauce
# 9335        9335       R Burgers             Zesty Dipping Sauce
#
#       menu_item_price                                restaurant_location  \
# 0               13.45  10361 Rockingham Drive, Sacramento, CA, 95827, US
# 1               14.10  10361 Rockingham Drive, Sacramento, CA, 95827, US
# 2               12.15  10361 Rockingham Drive, Sacramento, CA, 95827, US
# 3               14.10  10361 Rockingham Drive, Sacramento, CA, 95827, US
# 4               14.10  10361 Rockingham Drive, Sacramento, CA, 95827, US
# ...               ...                                                ...
# 9331             0.25               2590 Geer Rd, Turlock, CA, 95382, US
# 9332             0.25               2590 Geer Rd, Turlock, CA, 95382, US
# 9333             0.25               2590 Geer Rd, Turlock, CA, 95382, US
# 9334             0.25               2590 Geer Rd, Turlock, CA, 95382, US
# 9335             0.25               2590 Geer Rd, Turlock, CA, 95382, US
#
#                                       inputted_location restaurant_rating  \
# 0     10361 Rockingham Drive, Sacramento, CA, 95827, US              0 mi
# 1     10361 Rockingham Drive, Sacramento, CA, 95827, US              0 mi
# 2     10361 Rockingham Drive, Sacramento, CA, 95827, US              0 mi
# 3     10361 Rockingham Drive, Sacramento, CA, 95827, US              0 mi
# 4     10361 Rockingham Drive, Sacramento, CA, 95827, US              0 mi
# ...                                                 ...               ...
# 9331                  2505 3rd St, Ceres, CA, 95307, US               4.3
# 9332                  2505 3rd St, Ceres, CA, 95307, US               4.3
# 9333                  2505 3rd St, Ceres, CA, 95307, US               4.3
# 9334                  2505 3rd St, Ceres, CA, 95307, US               4.3
# 9335                  2505 3rd St, Ceres, CA, 95307, US               4.3
#
#      number_of_ratings restaurant_distance
# 0                  NaN                  •
# 1                  NaN                  •
# 2                  NaN                  •
# 3                  NaN                  •
# 4                  NaN                  •
# ...                ...                 ...
# 9331                62                8 mi
# 9332                62                8 mi
# 9333                62                8 mi
# 9334                62                8 mi
# 9335                62                8 mi
#
# [9466 rows x 9 columns]

# %%
"raw_prices_ubereats_ca_fflocal_03292024.csv", "raw_prices_ubereats_ca_fflocal05272024.csv"),

# %%
file_pairs = [
    ("raw_prices_ubereats_ca_fflocal_03292024.csv", "final_ca_localff.csv")
]

# Initialize a dictionary to store missing addresses by restaurant name
missing_restaurants_ubereats = {}

# Loop through each pair of file paths
for file_pair in file_pairs:
    # Extract the file paths for rounds 1 and 2
    file_path_1 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[0]
    file_path_2 = "/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/" + file_pair[1]

    # Load the CSV files
    df_rnd_1 = pd.read_csv(file_path_1)
    df_rnd_2 = pd.read_csv(file_path_2, low_memory=False)
    
    # Convert the addresses to lowercase
    df_rnd_1['restaurant_location'] = df_rnd_1['restaurant_location'].str.lower()
    df_rnd_2['restaurant_location'] = df_rnd_2['restaurant_location'].str.lower()
    
    #Replace Restaurant Names
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace('BJ', "BJ's Restaurants", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("Chili's", "Chili's Grill & Bar", case=False)
    df_rnd_2['restaurant_name'] = df_rnd_2['restaurant_name'].str.replace("TGI Friday", "TGI Fridays", case=False)




    # Extract the restaurant names and addresses as dictionaries
    restaurants_rnd_1 = df_rnd_1.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    restaurants_rnd_2 = df_rnd_2.groupby('restaurant_name')['restaurant_location'].apply(set).to_dict()
    
    # Find missing addresses for each restaurant
    for restaurant, addresses_rnd_1 in restaurants_rnd_1.items():
        addresses_rnd_2 = restaurants_rnd_2.get(restaurant, set())
        missing_addresses = addresses_rnd_1 - addresses_rnd_2
        if missing_addresses:
            if restaurant not in missing_restaurants_ubereats:
                missing_restaurants_ubereats[restaurant] = []
            missing_restaurants_ubereats[restaurant].extend(missing_addresses)
        
        # Calculate the percentage of missing addresses for the current restaurant
        total_addresses_rnd_1 = len(addresses_rnd_1)
        if total_addresses_rnd_1 != 0:
            percent_missing = (len(missing_addresses) / total_addresses_rnd_1) * 100
            print(f"Percentage of missing addresses for {restaurant}: {percent_missing:.2f}%")

# Print the final dictionary of missing addresses
print("\nFinal dictionary of missing addresses by restaurant name:")
for restaurant, addresses in missing_restaurants_ubereats.items():
    print(f"{restaurant}: {addresses}")
# Out:
# Percentage of missing addresses for Betty Burgers: 0.00%
# Percentage of missing addresses for Big Mouth Burgers: 0.00%
# Percentage of missing addresses for Burger Basket: 0.00%
# Percentage of missing addresses for Burger Boss: 0.00%
# Percentage of missing addresses for Burger Factory: 0.00%
# Percentage of missing addresses for Burger Palace: 0.00%
# Percentage of missing addresses for Burger Station: 0.00%
# Percentage of missing addresses for Cypress Best Burgers: 0.00%
# Percentage of missing addresses for Gold Star Hamburgers: 0.00%
# Percentage of missing addresses for Hook Burger: 0.00%
# Percentage of missing addresses for P & G Burgers: 0.00%
# Percentage of missing addresses for R Burgers: 0.00%
# Percentage of missing addresses for Super Burger: 0.00%
# Percentage of missing addresses for Varsity Burgers: 0.00%
#
# Final dictionary of missing addresses by restaurant name:

# %%
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_ca_ff_03222024.csv") 
post_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_ca_ff_05142024.csv") 
final_post = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_processed_prices_ubereats_ca_ff_05142024.csv")

# %%
prev_data['restaurant_location']
# Out:
#       Unnamed: 0  restaurant_name  \
# 0              0         McDonald
# 1              1      Burger King
# 2              2         McDonald
# 3              3         McDonald
# 4              4  Jack in the Box
# ...          ...              ...
# 1135        1135        Five Guys
# 1136        1136        Five Guys
# 1137        1137        Five Guys
# 1138        1138        Five Guys
# 1139        1139        Five Guys
#
#                                     restaurant_location  \
# 0     100 e redlands blvd, san bernardino, ca, 92408...
# 1      205 east redlands, san bernardino, ca, 92408, us
# 2              1000 e 4th st, long beach, ca, 90802, us
# 3        640 long beach blvd, long beach, ca, 90802, us
# 4           652 atlantic ave, long beach, ca, 90802, us
# ...                                                 ...
# 1135  5650 balboa ave suite 101, san diego, ca, 9211...
# 1136      6285 pats ranch rd., mira loma, ca, 91752, us
# 1137       6660 lone tree way, brentwood, ca, 94513, us
# 1138  8420 balboa blvd. suite 115, northridge, ca, 9...
# 1139             8901 apollo way, downey, ca, 90242, us
#
#       menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                          6.522047                             5.59
# 1                          8.970256                             6.69
# 2                          7.439231                             5.19
# 3                          5.264737                             3.79
# 4                          8.162628                             7.49
# ...                             ...                              ...
# 1135                       9.900345                             9.95
# 1136                       8.290690                             8.27
# 1137                       8.319655                             8.63
# 1138                       9.875517                            10.07
# 1139                       9.908621                            10.07
#
#       menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                         4.706970                     4.6              144
# 1                         5.813355                     4.1               78
# 2                         5.679119                     4.7              141
# 3                         4.269700                     4.4              134
# 4                         4.660305                     4.3              137
# ...                            ...                     ...              ...
# 1135                      3.705692                     4.6               58
# 1136                      3.177414                     4.5               58
# 1137                      3.386572                     4.8               29
# 1138                      3.699241                     4.8               29
# 1139                      3.707268                     4.7               29
#
#      number_of_ratings first  specialty_item  ...  hamburger  fries  state  \
# 0                         34            7.89  ...       3.49   5.89     ca
# 1                         15           10.29  ...       5.39   4.89     ca
# 2                        137            8.29  ...       3.89   5.29     ca
# 3                       200+            6.46  ...       2.95   4.59     ca
# 4                        113            6.86  ...       3.11   3.74     ca
# ...                      ...             ...  ...        ...    ...    ...
# 1135                      90           15.47  ...      11.15   8.75     ca
# 1136                      31           13.19  ...       9.23   7.19     ca
# 1137                      40           13.55  ...       9.59   6.95     ca
# 1138                      76           15.47  ...      11.15   8.75     ca
# 1139                      53           15.47  ...      11.15   8.75     ca
#
#         zip     county_name        date uber_eats post_policy  fast_food  \
# 0     92408  San Bernardino  2024-03-22         1           0          1
# 1     92408  San Bernardino  2024-03-22         1           0          1
# 2     90802     Los Angeles  2024-03-22         1           0          1
# 3     90802     Los Angeles  2024-03-22         1           0          1
# 4     90802     Los Angeles  2024-03-22         1           0          1
# ...     ...             ...         ...       ...         ...        ...
# 1135  92117       San Diego  2024-03-22         1           0          1
# 1136  91752       Riverside  2024-03-22         1           0          1
# 1137  94513    Contra Costa  2024-03-22         1           0          1
# 1138  91343     Los Angeles  2024-03-22         1           0          1
# 1139  90242     Los Angeles  2024-03-22         1           0          1
#
#       local
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1135      0
# 1136      0
# 1137      0
# 1138      0
# 1139      0
#
# [1140 rows x 22 columns]

# %%
len(post_data['county_name'].unique())
# Out:
# 29

# %%
len(final_post['county_name'].unique())
# Out:
# 42

# %%
prev_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_nonca_ff_03292024.csv") 
post_data = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/processed_prices_ubereats_nonca_ff_05162024.csv") 
final_post = pd.read_csv("/Users/alyssanguyen/Desktop/IRLE_scraping/csv_files/final_processed_prices_ubereats_nonca_ff_05162024.csv")

# %%
prev_data
# Out:
#       Unnamed: 0.1  Unnamed: 0 restaurant_name  \
# 0                0           0        McDonald
# 1                1           1     Burger King
# 2                2           2           Sonic
# 3                3           3        McDonald
# 4                4           4        McDonald
# ...            ...         ...             ...
# 1112            92          92         Hardees
# 1113            93          93         Hardees
# 1114            94          94         Hardees
# 1115            95          95         Hardees
# 1116            96          96         Hardees
#
#                                     restaurant_location  \
# 0           1 a gateway blvd e, savannah, ga, 31419, us
# 1           11711 abercorn st., savannah, ga, 31419, us
# 2           396 canebrake road, savannah, ga, 31419, us
# 3             1001 n 9th street, reading, pa, 19604, us
# 4          101 s expressway, brownsville, tx, 78520, us
# ...                                                 ...
# 1112  9020 east 21st street, indianapolis, in, 46229...
# 1113        915 army post rd, des moines, ia, 50315, us
# 1114  917 allison-bonnett memorial dr, hueytown, al,...
# 1115    940 thornton rd., lithia springs, ga, 30122, us
# 1116  roebuck parkway east &amp; red lane rd, birmin...
#
#       menu_item_price mean_non_zero  menu_item_price median_non_zero  \
# 0                          5.557153                            4.090
# 1                          7.625190                            6.090
# 2                          4.243333                            3.890
# 3                          6.820000                            4.690
# 4                          5.464964                            4.390
# ...                             ...                              ...
# 1112                       6.876190                            5.875
# 1113                       8.299184                            6.860
# 1114                       7.540851                            6.060
# 1115                       7.817955                            6.885
# 1116                       7.445652                            6.640
#
#       menu_item_price std_non_zero  restaurant_rating mean  menu_item count  \
# 0                         4.649372                     4.3              151
# 1                         5.759805                     4.3               79
# 2                         1.936687                     4.7               86
# 3                         5.206265                     4.3              149
# 4                         3.326133                     4.3              144
# ...                            ...                     ...              ...
# 1112                      4.879454                     0.0              134
# 1113                      7.098840                     3.6               76
# 1114                      5.794948                     0.0               74
# 1115                      6.171346                     4.5               71
# 1116                      5.420510                     4.2               73
#
#      number_of_ratings first  ...  hamburger  fries  state    zip  \
# 0                         12  ...       2.29   3.39     ga  31419
# 1                         31  ...       3.39   3.69     ga  31419
# 2                         35  ...        NaN   0.00     ga  31419
# 3                        50+  ...       3.59   5.19     pa  19604
# 4                         23  ...       3.21   3.89     tx  78520
# ...                      ...  ...        ...    ...    ...    ...
# 1112                       2  ...        NaN   2.87     in  46229
# 1113                      30  ...        NaN   3.24     ia  50315
# 1114                      15  ...        NaN   2.77     al  35023
# 1115                      24  ...        NaN   3.38     ga  30122
# 1116                      12  ...        NaN   2.77     al  35215
#
#       county_name        date  uber_eats post_policy fast_food  local
# 0         Chatham  2024-03-29          1           0         1      0
# 1         Chatham  2024-03-29          1           0         1      0
# 2         Chatham  2024-03-29          1           0         1      0
# 3           Berks  2024-03-29          1           0         1      0
# 4         Cameron  2024-03-29          1           0         1      0
# ...           ...         ...        ...         ...       ...    ...
# 1112       Marion  2024-03-28          1           0         1      0
# 1113         Polk  2024-03-28          1           0         1      0
# 1114    Jefferson  2024-03-28          1           0         1      0
# 1115      Douglas  2024-03-28          1           0         1      0
# 1116    Jefferson  2024-03-28          1           0         1      0
#
# [1117 rows x 23 columns]

# %%
len(post_data['restaurant_location'])
# Out:
# 1792

# %%
len(final_post['restaurant_location'].unique())
# Out:
# 2257
